# %% [markdown]
# # 우회전 유스케이스 분석
#
# ![description](imgs/image_RT.png)

# %%
# 상태에 min_spacing등만 넣을게 아니라, min2_spacing 등 추가
# state 변경 8개
#     """
#     State Vector (예시: 13차원)
#     0:  ego_speed           (0~1, 50 km/h 기준 정규화)
#     1:  dtc_norm            (0~1, 충돌지점까지 남은 거리 / 200 m)
#     2:  time_to_Gn_norm     (0~1, GN까지 남은 시간 / 100 s)
#     3:  f1_spacing_norm     (0~1, 가장 가까운 following spacing)
#     4:  f1_ttc_norm         (0~1, 가장 가까운 following TTC)
#     5:  f1_rel_speed_norm   (~[-1,1], 가장 가까운 following 상대속도)
#     6:  f2_spacing_norm     (0~1, 두 번째 following spacing)
#     7:  f2_ttc_norm         (0~1, 두 번째 following TTC)
#     8:  c1_spacing_norm     (0~1, 가장 가까운 crossing spacing)
#     9:  c1_pet_norm         (0~1, 가장 가까운 crossing PET)
#     10: c2_spacing_norm     (0~1, 두 번째 crossing spacing)
#     11: c2_pet_norm         (0~1, 두 번째 crossing PET)
#     12: dummy_cross_rel     (~[-1,1], crossing 상대속도 자리(현재 0.0, 추후 확장용))
#     """
    
# 앞뒤차 4대

# %%
"""
VISSIM TD3 Template for Single-Ego Accel Control at Signalized Intersection
- Author: Kawon Kang
- Purpose: Single vehicle (ego) continuous accel guidance via TD3
- Control: action a_t [m/s^2] -> target desired speed (DesSpeed) for ego
- Safety layer + yellow dilemma rule as post-processing on action
"""

# basic libraries
import os
import sys
import random
import math
import time
from dataclasses import dataclass
from typing import Dict, Any, Tuple, Optional

# VISSIM COM
import win32com.client as COM

# data libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.rc('font', family='Malgun Gothic')
# %matplotlib inline
plt.rcParams['axes.unicode_minus'] = False


# -----------------------------
# PyTorch 기반 TD3
# -----------------------------

import torch
import torch.nn as nn
import torch.optim as optim


from collections import deque, defaultdict

# 재현성
torch.manual_seed(42)
np.random.seed(42)
random.seed(42)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# PPO, DDPG, TD3 모델

# %%
# =========================
# VISSIM 유틸 (원본 최대 유지)
# =========================
def is_vehicle_valid(vehicle):
    try:
        vehicle.AttValue('No')
        vehicle.AttValue('Speed')
        vehicle.AttValue('Pos')
        return True
    except:
        return False

def get_valid_vehicles(Vissim):
    try:
        vehicles = []
        for vehicle in Vissim.Net.Vehicles:
            try:
                vehicle_no = vehicle.AttValue('No')
                vehicle_pos = vehicle.AttValue('Pos')
                vehicle_speed = vehicle.AttValue('Speed')
                vehicle_link = vehicle.AttValue('Lane')
                if all(attr is not None for attr in [vehicle_no, vehicle_pos, vehicle_speed, vehicle_link]):
                    vehicles.append(vehicle)
            except:
                continue
        return vehicles
    except Exception as e:
        print(f"Error in get_valid_vehicles: {str(e)}")
        return []
def reset_network(Vissim):
        # try:
    Vissim.Simulation.Stop()
    try:
        for vehicle in list(Vissim.Net.Vehicles):
            try:
                Vissim.Net.Vehicles.RemoveVehicle(vehicle.AttValue('No'))
            except:
                continue
    except:
        pass
def create_vehicles(Vissim, link_ranges):
    # try:
    Vissim.Simulation.Stop()
    try:
        for vehicle in list(Vissim.Net.Vehicles):
            try:
                Vissim.Net.Vehicles.RemoveVehicle(vehicle.AttValue('No'))
            except:
                continue
    except:
        pass
    time.sleep(0.2)
    cv_rand = np.random.randint(1, 100)
    Vissim.Simulation.SetAttValue('RandSeed', cv_rand)
    Vissim.Simulation.RunSingleStep()

    for _ in range(np.random.randint(85,100)): # 80~ 100초까지 warm-up 100초에 남직신호 시작
        Vissim.Simulation.RunSingleStep()
    
    created_vehicles = []
    regular_vehicles = [
        (11, link_ranges[1][0], link_ranges[1][1], 1), # link, start_pos, end_pos, veh_num
        (11, link_ranges[2][0], link_ranges[2][1], 2), 
        (11, link_ranges[3][0], link_ranges[3][1], 3),
        (11, link_ranges[4][0], link_ranges[4][1], 4)
    ]
    for link, start_pos, end_pos, veh_num in regular_vehicles:
        vehicle = Vissim.Net.Vehicles.AddVehicleAtLinkPosition( #주변 차량 생성
            100, link, (veh_num+1)//2 , np.random.uniform(start_pos, end_pos), 40, True #Type, Lane, Pos, DesSpeed, Interaction(Opt)-> 주변객체 상호작용 여부
        )
        if vehicle:
            vehicle.SetAttValue('DesSpeed', 40) # 물어보기
            # vehicle.SetAttValue('DesLane', random.choice([1,2])) # 조정필요
            created_vehicles.append(vehicle)
            time.sleep(0.1)

    ego_pos = np.random.uniform(50, 60) # 조정필요
    ego_vehicle = Vissim.Net.Vehicles.AddVehicleAtLinkPosition(
        630, 11, np.random.choice([1,2]), ego_pos, 50, True 
    )
    if ego_vehicle:
        ego_vehicle.SetAttValue('DesSpeed', 50)
        ego_vehicle.SetAttValue('DesLane', 1) # 우회전만 하라.
        created_vehicles.append(ego_vehicle)
        time.sleep(0.2)

    # follower_pos = ego_pos - 30
    # if follower_pos >= link_ranges[3][0]:
    #     follower = Vissim.Net.Vehicles.AddVehicleAtLinkPosition(
    #         100, 3, 1, follower_pos, 40, True 
    #     )
    #     if follower:
    #         follower.SetAttValue('DesSpeed', 50)
    #         created_vehicles.append(follower)

    if len(created_vehicles) > 3:
        time.sleep(0.2)
        Vissim.Simulation.RunSingleStep()
        return created_vehicles
    return None
    # except Exception as e:
    #     print(f"Error in create_vehicles: {str(e)}")
    #     return None

# %%
LINK_LENGTHS = {
    "11-1": 149.4,
    "11-2": 149.4,
    "10002-1": 39.76,
    "4-1": 18.22,
    "9-1": 160.03,
    "10009-1": 40.89,
    "7-1": 200.0  # 필요 시 실제 길이로 수정
}

def get_dist_to_conflict(link_id, pos, role="ego"):
    """상충 지점까지의 남은 거리(DTC) 계산"""
    dtc = 1000.0
    try:
        link_id = str(link_id)
        if role == "ego":
            if link_id in ["11-1", "11-2"]:
                dtc = (LINK_LENGTHS["11-1"] - pos) + LINK_LENGTHS["10002-1"] + LINK_LENGTHS["4-1"]
            elif link_id == "10002-1":
                dtc = (LINK_LENGTHS["10002-1"] - pos) + LINK_LENGTHS["4-1"]
            elif link_id == "4-1":
                dtc = (LINK_LENGTHS["4-1"] - pos)
            elif link_id == "7-1":
                dtc = -pos
        elif role == "other":
            if link_id == "9-1":
                dtc = (LINK_LENGTHS["9-1"] - pos) + LINK_LENGTHS["10009-1"]
            elif link_id == "10009-1":
                dtc = (LINK_LENGTHS["10009-1"] - pos)
            elif link_id == "7-1":
                dtc = -pos
    except:
        pass
    return dtc

def calculate_observations(vehicle_list, ego_num=5):
    """
    모든 차량에 대해 Spacing과 시간지표(TTC/PET)를 계산.
    obs_dict[key] = {
        'type': 'following' or 'crossing',
        'spacing': ...,
        'ttc': ... (following),
        'pet': ... (crossing),
        ...
    }
    """
    obs_dict = {}
    ego_vehicle = None
    
    # Ego 찾기
    for vehicle in vehicle_list:
        if vehicle.AttValue('No') == ego_num:
            ego_vehicle = vehicle
            break
    if not ego_vehicle:
        return obs_dict

    ego_link = str(ego_vehicle.AttValue('Lane'))
    ego_pos  = float(ego_vehicle.AttValue('Pos'))
    ego_speed = float(ego_vehicle.AttValue('Speed') or 0) / 3.6
    dtc_ego = get_dist_to_conflict(ego_link, ego_pos, role="ego")

    crossing_target_links = ["9-1", "10009-1"]

    for other_vehicle in vehicle_list:
        oid = other_vehicle.AttValue('No')
        if oid == ego_num:
            continue

        other_link = str(other_vehicle.AttValue('Lane'))
        other_pos = float(other_vehicle.AttValue('Pos'))
        other_speed = float(other_vehicle.AttValue('Speed') or 0) / 3.6
        
        # 1) 같은 차선: following
        if ego_link == other_link and other_pos > ego_pos:
            spacing = other_pos - ego_pos
            rel_speed = ego_speed - other_speed
            ttc = spacing / (rel_speed + 1e-6) if rel_speed > 0 else 100.0

            if spacing < 60:
                obs_dict[f"{ego_num}_{oid}"] = {
                    "type": "following",
                    "spacing": spacing,
                    "ttc": ttc,
                    "rel_speed": rel_speed
                }

        # 2) 교차 차선: crossing
        elif (other_link in crossing_target_links) and (dtc_ego > -5):
            dtc_other = get_dist_to_conflict(other_link, other_pos, role="other")
            if dtc_other > -5:
                spacing = max(0, dtc_ego) + max(0, dtc_other)
                tta_ego = dtc_ego / max(ego_speed, 0.1)
                tta_other = dtc_other / max(other_speed, 0.1)
                pet = abs(tta_ego - tta_other)

                if tta_ego < 20:
                    obs_dict[f"{ego_num}_{oid}"] = {
                        "type": "crossing",
                        "spacing": spacing,
                        "pet": pet,
                        "tta_ego": tta_ego,
                        "tta_other": tta_other
                    }

    return obs_dict


def get_reward(vehicle, obs_dict):
    if vehicle is None: return 0.0, False
    
    reward = 1 # 생존 보상
    done = False
    
    # 가장 위험한 값 추출 (Spacing도 보고, 시간도 봄)
    min_spacing = 1000.0
    min_time_metric = 1000.0 # TTC or PET
    
    for _, data in obs_dict.items():
        # 거리 갱신 (무조건 가까우면 장땡)
        if data['spacing'] < min_spacing:
            min_spacing = data['spacing']
        
        # 시간 갱신 (유형별로 위험도 판단)
        if data['type'] == 'following':
            if data['ttc'] < min_time_metric: min_time_metric = data['ttc']
        elif data['type'] == 'crossing':
            if data['pet'] < min_time_metric: min_time_metric = data['pet']

    # --------------------------------------------------------
    # [보상 로직] Spacing과 Time Metric을 모두 사용
    # --------------------------------------------------------
    
    # 1. Spacing 기반 (물리적 충돌 방지 - 최우선)
    if min_spacing < 2.0: # 충돌
        reward -= 200
        return float(reward), True # 종료
    elif min_spacing < 5.0: # 너무 가까움
        reward -= 10
    elif min_spacing < 10.0: # 주의
        reward -= 2

    # 2. Time 기반 (예측 위험 회피)
    # 거리가 좀 있어도(20m), 속도가 빨라서 TTC/PET가 1초면 위험한 상황
    if min_time_metric < 1.5: # 급위험
        reward -= 10
    elif min_time_metric < 3.0: # 주의
        reward -= 2

    # 3. 속도 보상 (추가)
    ego_speed = float(vehicle.AttValue('Speed') or 0)
    if 30 <= ego_speed <= 50:
        reward += 1.0

    return float(reward), done

# %%
def get_state(vehicles, obs_dict, ego_num, simsec):
    """
    State Vector (예시: 13차원)
    0:  ego_speed           (0~1, 50 km/h 기준 정규화)
    1:  dtc_norm            (0~1, 충돌지점까지 남은 거리 / 200 m)
    2:  time_to_Gn_norm     (0~1, GN까지 남은 시간 / 100 s)
    3:  f1_spacing_norm     (0~1, 가장 가까운 following spacing)
    4:  f1_ttc_norm         (0~1, 가장 가까운 following TTC)
    5:  f1_rel_speed_norm   (~[-1,1], 가장 가까운 following 상대속도)
    6:  f2_spacing_norm     (0~1, 두 번째 following spacing)
    7:  f2_ttc_norm         (0~1, 두 번째 following TTC)
    8:  c1_spacing_norm     (0~1, 가장 가까운 crossing spacing)
    9:  c1_pet_norm         (0~1, 가장 가까운 crossing PET)
    10: c2_spacing_norm     (0~1, 두 번째 crossing spacing)
    11: c2_pet_norm         (0~1, 두 번째 crossing PET)
    12: dummy_cross_rel     (~[-1,1], crossing 상대속도 자리(현재 0.0, 추후 확장용))
    """
    try:
        ego_vehicle = next((v for v in vehicles if v.AttValue('No') == ego_num), None)
        if not ego_vehicle:
            # state_dim과 길이 맞춰서 리턴
            return np.zeros(13, dtype=np.float32)

        # 1. Ego 정보
        ego_speed = float(ego_vehicle.AttValue('Speed') or 0) / 50.0  # 50 km/h 기준
        ego_link  = ego_vehicle.AttValue('Lane')                # 링크 ID
        ego_pos   = float(ego_vehicle.AttValue('Pos') or 0)

        # DTC (충돌지점까지 남은 거리)
        dtc_ego = get_dist_to_conflict(ego_link, ego_pos, role="ego")
        dtc_norm = min(max(dtc_ego, 0.0) / 200.0, 1.0)                # 0~200 m 기준

        # 2. 신호까지 남은 시간 (예: 0~100초)
        time_to_Gn = max(0.0, 100.0 - float(simsec))                  # 임시 예시
        time_to_Gn_norm = min(time_to_Gn / 100.0, 1.0)

        # 3. Following / Crossing 리스트 생성
        following_list = []   # [{'spacing_norm':..., 'ttc_norm':..., 'rel_speed_norm':...}, ...]
        crossing_list  = []   # [{'spacing_norm':..., 'pet_norm':...}, ...]

        if obs_dict:
            for _, data in obs_dict.items():
                if data['type'] == 'following':
                    spacing_norm = min(data['spacing'] / 100.0, 1.0)
                    ttc_norm     = min(data['ttc']     / 20.0, 1.0)
                    rel_speed_norm = (data['rel_speed'] / 50.0)  # km/h 기준이면 /50

                    following_list.append({
                        'spacing_norm': spacing_norm,
                        'ttc_norm': ttc_norm,
                        'rel_speed_norm': rel_speed_norm
                    })

                elif data['type'] == 'crossing':
                    spacing_norm = min(data['spacing'] / 100.0, 1.0)
                    pet_norm     = min(data['pet']     / 20.0, 1.0)
                    rel_speed_norm = (data['rel_speed'] / 50.0)  # km/h 기준이면 /50

                    crossing_list.append({
                        'spacing_norm': spacing_norm,
                        'pet_norm': pet_norm,
                        'rel_speed_norm': rel_speed_norm
                    })

        # 4. spacing 기준으로 정렬 후 상위 2개만 사용, 부족하면 패딩
        following_list.sort(key=lambda x: x['spacing_norm'])
        crossing_list.sort(key=lambda x: x['spacing_norm'])

        follow_default = {'spacing_norm': 1.0, 'ttc_norm': 1.0, 'rel_speed_norm': 0.0}
        cross_default  = {'spacing_norm': 1.0, 'pet_norm': 1.0, 'rel_speed_norm': 0.0}

        while len(following_list) < 2:
            following_list.append(follow_default)
        while len(crossing_list) < 2:
            crossing_list.append(cross_default)

        f1, f2 = following_list[0], following_list[1]
        c1, c2 = crossing_list[0], crossing_list[1]

        
        state = np.array([
            ego_speed,
            dtc_norm,
            time_to_Gn_norm,
            f1['spacing_norm'],
            f1['ttc_norm'],
            f1['rel_speed_norm'],
            f2['spacing_norm'],
            f2['ttc_norm'],
            c1['spacing_norm'],
            c1['pet_norm'],
            c1['rel_speed_norm'],
            c2['spacing_norm'],
            c2['pet_norm']
        ], dtype=np.float32)

        return state

    except Exception as e:
        print(f"Error in get_state: {str(e)}")
        return np.zeros(13, dtype=np.float32)





def apply_action(vehicle_list, Vissim, acceleration):
    try:
        for vehicle in vehicle_list:
            if vehicle.AttValue('VehType') == '630':
                current_speed = vehicle.AttValue('Speed')  # km/h
                speed_ms = current_speed / 3.6
                delta_v = float(acceleration) * 1  # 1초 스텝
                new_speed_ms = speed_ms + delta_v
                new_speed_ms = max(30/3.6, min(new_speed_ms, 50/3.6))
                vehicle.SetAttValue('DesSpeed', new_speed_ms * 3.6)
                break
    except Exception as e:
        print(f"Error applying action: {str(e)}")


def is_episode_done(ego_vehicle, obs_dict):
    try:
        if ego_vehicle is None:
            return False
        
        ego_link = str(ego_vehicle.AttValue('Lane'))
        ego_pos  = float(ego_vehicle.AttValue('Pos'))

        # 목표 지점 도달
        if ego_link == "7-1" and ego_pos > 30:
            print("Episode done: Reached target point.")
            return True

        # 충돌 조건
        for _, data in obs_dict.items():
            if data['spacing'] < 2.0:
                return True

        # 비정상 속도
        speed = float(ego_vehicle.AttValue('Speed'))
        if speed < 0 or speed > 70:
            print("Abnormal speed detected:", speed)
            return True

        return False
    except Exception as e:
        print(f"Error checking episode completion: {str(e)}")
        return False


def Network(Network_Path, inpx_Name, layx_Name):
    # try:
    Vissim = COM.Dispatch("Vissim.Vissim")
    Filename = os.path.join(Network_Path, inpx_Name)
    flag_read_additionally = False
    Vissim.LoadNet(Filename, flag_read_additionally)
    Filename = os.path.join(Network_Path, layx_Name)
    Vissim.LoadLayout(Filename)
    for simRun in Vissim.Net.SimulationRuns:
        Vissim.Net.SimulationRuns.RemoveSimulationRun(simRun)
    return Vissim
    
    # except Exception as e:
    #     print(f"Error initializing Vissim: {str(e)}")
    #     return None

# %%
# =========================
# Replay Buffer (TD3용)
# =========================
class ReplayBuffer:
    def __init__(self, capacity=100000):
        self.buffer = deque(maxlen=capacity)

    def push(self, state, action, reward, next_state, done):
        # action: float 가속도
        self.buffer.append((np.array(state, dtype=np.float32),
                            float(action),
                            float(reward),
                            np.array(next_state, dtype=np.float32),
                            float(done)))

    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        states, actions, rewards, next_states, dones = zip(*batch)
        states      = np.array(states, dtype=np.float32)
        actions     = np.array(actions, dtype=np.float32).reshape(-1, 1)  # (B,1)
        rewards     = np.array(rewards, dtype=np.float32).reshape(-1, 1)
        next_states = np.array(next_states, dtype=np.float32)
        dones       = np.array(dones, dtype=np.float32).reshape(-1, 1)
        
        # 라이트 클립으로 수치 안정화
        states      = np.clip(states, -10, 10)
        next_states = np.clip(next_states, -10, 10)
        rewards     = np.clip(rewards, -100, 100)
        return states, actions, rewards, next_states, dones

    def __len__(self):
        return len(self.buffer)


# =========================
# TD3 네트워크
# =========================
class Actor(nn.Module):
    def __init__(self, state_dim, act_low=-3.0, act_high=3.0):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(state_dim, 1024), nn.ReLU(),
            nn.Linear(1024, 512), nn.ReLU(),
            nn.Linear(512, 256), nn.ReLU(),
            nn.Linear(256, 1), nn.Tanh()  # [-1, 1]
        )
        # 행동 스케일
        self.register_buffer("act_low",  torch.tensor([act_low], dtype=torch.float32))
        self.register_buffer("act_high", torch.tensor([act_high], dtype=torch.float32))

    def forward(self, s):
        u = self.net(s)  # [-1,1]
        return (self.act_high - self.act_low) * 0.5 * u + (self.act_high + self.act_low) * 0.5


class Critic(nn.Module):
    def __init__(self, state_dim):
        super().__init__()
        def qnet():
            return nn.Sequential(
                nn.Linear(state_dim + 1, 400), nn.ReLU(),
                nn.Linear(400, 300), nn.ReLU(),
                nn.Linear(300, 1)
            )
        self.q1 = qnet()
        self.q2 = qnet()

    def forward(self, s, a):
        sa = torch.cat([s, a], dim=-1)
        return self.q1(sa), self.q2(sa)

    def q1_only(self, s, a):
        sa = torch.cat([s, a], dim=-1)
        return self.q1(sa)


# =========================
# TD3 Agent (PyTorch)
# =========================
class TD3Agent:
    def __init__(
        self,
        state_dim=13, # 상태 차원
        act_low=-3.0, # 가감속 범위
        act_high=3.0,
        actor_lr=1.5e-5,
        critic_lr=1.5e-4,
        gamma=0.99,
        tau=0.001,
        policy_noise=0.2,
        noise_clip=0.5,
        policy_delay=2,
        batch_size=512,
        start_steps=5000,
        expl_noise=0.2
    ):
        self.state_dim   = state_dim
        self.act_low     = act_low
        self.act_high    = act_high
        self.gamma       = gamma
        self.tau         = tau
        self.policy_noise= policy_noise
        self.noise_clip  = noise_clip
        self.policy_delay= policy_delay
        self.batch_size  = batch_size
        self.start_steps = start_steps
        self.expl_noise  = expl_noise

        self.actor     = Actor(state_dim, act_low, act_high).to(device)
        self.actor_t   = Actor(state_dim, act_low, act_high).to(device)
        self.critic    = Critic(state_dim).to(device)
        self.critic_t  = Critic(state_dim).to(device)

        self.actor_t.load_state_dict(self.actor.state_dict())
        self.critic_t.load_state_dict(self.critic.state_dict())

        self.opt_actor  = optim.Adam(self.actor.parameters(), lr=actor_lr)
        self.opt_critic = optim.Adam(self.critic.parameters(), lr=critic_lr)

        self.replay_buffer = ReplayBuffer(capacity=100000)
        self.total_it = 0

        # 로깅
        self.training_metrics = {
            'critic_losses': [],
            'actor_losses': [],
            'q_values': [],
            'rewards': []
        }

    @torch.no_grad()
    def select_action(self, state, training=True):
        """
        state: np.ndarray (state_dim,)
        return: float acceleration in [act_low, act_high]
        """
        s = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)  # (1, state_dim)
        if training and self.total_it < self.start_steps:
            a = np.random.uniform(self.act_low, self.act_high)
            return float(a)

        a = self.actor(s).cpu().numpy()[0, 0]
        if training:
            a += np.random.normal(0, self.expl_noise)
        return float(np.clip(a, self.act_low, self.act_high))

    def train_step(self):
        if len(self.replay_buffer) < self.batch_size:
            return

        self.total_it += 1
        s, a, r, s2, d = self.replay_buffer.sample(self.batch_size)

        s  = torch.tensor(s,  dtype=torch.float32, device=device)
        a  = torch.tensor(a,  dtype=torch.float32, device=device)
        r  = torch.tensor(r,  dtype=torch.float32, device=device)
        s2 = torch.tensor(s2, dtype=torch.float32, device=device)
        d  = torch.tensor(d,  dtype=torch.float32, device=device)

        # ----- Critic update -----
        with torch.no_grad():
            a2 = self.actor_t(s2)
            noise = (torch.randn_like(a2) * self.policy_noise).clamp(-self.noise_clip, self.noise_clip)
            a2 = (a2 + noise).clamp(self.act_low, self.act_high)
            q1_t, q2_t = self.critic_t(s2, a2)
            y = r + self.gamma * (1.0 - d) * torch.min(q1_t, q2_t)

        q1, q2 = self.critic(s, a)
        critic_loss = (q1 - y).pow(2).mean() + (q2 - y).pow(2).mean()

        self.opt_critic.zero_grad()
        critic_loss.backward()
        nn.utils.clip_grad_norm_(self.critic.parameters(), 1.0)
        self.opt_critic.step()

        actor_loss = torch.tensor(0.0, device=device)
        # ----- Delayed policy update -----
        if self.total_it % self.policy_delay == 0:
            a_pred = self.actor(s)
            actor_loss = -self.critic.q1_only(s, a_pred).mean()
            self.opt_actor.zero_grad()
            actor_loss.backward()
            nn.utils.clip_grad_norm_(self.actor.parameters(), 1.0)
            self.opt_actor.step()

            # Polyak update
            with torch.no_grad():
                for p, pt in zip(self.actor.parameters(), self.actor_t.parameters()):
                    pt.data.mul_(1 - self.tau)
                    pt.data.add_(self.tau * p.data)
                for p, pt in zip(self.critic.parameters(), self.critic_t.parameters()):
                    pt.data.mul_(1 - self.tau)
                    pt.data.add_(self.tau * p.data)

        # 로깅
        with torch.no_grad():
            self.training_metrics['critic_losses'].append(float(critic_loss.item()))
            self.training_metrics['actor_losses'].append(float(actor_loss.item()) if self.total_it % self.policy_delay == 0 else np.nan)
            self.training_metrics['q_values'].append(float(q1.mean().item()))

    # 저장/로드 (경량)
    def save_models(self, path):
        os.makedirs(path, exist_ok=True)
        torch.save(self.actor.state_dict(),  os.path.join(path, "actor.pt"))
        torch.save(self.critic.state_dict(), os.path.join(path, "critic.pt"))
        np.save(os.path.join(path, "train_meta.npy"), {"total_it": self.total_it})

    def load_models(self, path):
        self.actor.load_state_dict(torch.load(os.path.join(path, "actor.pt"), map_location=device))
        self.critic.load_state_dict(torch.load(os.path.join(path, "critic.pt"), map_location=device))
        self.actor_t.load_state_dict(self.actor.state_dict())
        self.critic_t.load_state_dict(self.critic.state_dict())
        meta_path = os.path.join(path, "train_meta.npy")
        if os.path.exists(meta_path):
            meta = np.load(meta_path, allow_pickle=True).item()
            self.total_it = int(meta.get("total_it", 0))


# =========================
# 평가 루틴 (TD3)
# =========================
def evaluate(Vissim, agent, link_ranges, num_episodes=1000):
    results = []
    for episode in range(num_episodes):
        vehicles = None
        while vehicles is None:
            vehicles = create_vehicles(Vissim, link_ranges)
            time.sleep(0.1)
        if vehicles is None:
            continue

        episode_reward = 0.0
        step = 0
        while True:
            try:
                vehicles = get_valid_vehicles(Vissim)
                if not vehicles:
                    break
                ego_vehicle = None
                ego_vehicle = next((v for v in vehicles if v.AttValue('VehType') == '630'), None)
                if ego_vehicle is None:
                    break

                ego_num = ego_vehicle.AttValue('No')
                # ---- obs/state 생성 ----
                obs_dict = calculate_observations(vehicles, ego_num=ego_num)
                current_state = get_state(vehicles, obs_dict, ego_num=ego_num, simsec=Vissim.Simulation.AttValue('SimSec'))
                # ---- 액션 선택 및 적용 ----
                acceleration = agent.select_action(current_state, training=False)
                apply_action(vehicles, Vissim, acceleration)
                Vissim.Simulation.RunSingleStep()

                next_vehicles = get_valid_vehicles(Vissim)
                if not next_vehicles:
                    break

                next_obs = calculate_observations(next_vehicles, ego_num=ego_num, simsec=Vissim.Simulation.AttValue('SimSec'))
                next_state = get_state(next_vehicles, next_obs, ego_num=ego_num, simsec=Vissim.Simulation.AttValue('SimSec'))

                # ---- 보상 계산 ----
                reward, done = get_reward(ego_vehicle, next_obs)
                episode_reward += reward

                results.append({
                    'Episode': episode + 1,
                    'Step': step + 1,
                    'Speed': ego_vehicle.AttValue('Speed'),
                    'Position': ego_vehicle.AttValue('Pos'),
                    'Link': ego_vehicle.AttValue('Lane')
                })

                if done or is_episode_done(ego_vehicle, next_obs):
                    break
                step += 1
                time.sleep(0.05)

            except Exception as e:
                print(f"Error during evaluation step: {str(e)}")
                break
            
        print(f"Evaluation Episode {episode + 1}: Reward = {episode_reward:.2f}")
    return pd.DataFrame(results)

# %%
# =========================
# 학습 모니터 (원본 유지)
# =========================
class LearningMonitor:
    def __init__(self):
        self.metrics = defaultdict(list)
        self.episode_data = []
        self.episode_summaries = []

    def add_episode_data(self, data):
        """에피소드 데이터 추가"""
        self.episode_data.append(data)
         # 에피소드 인덱스
        ep_idx = len(self.episode_summaries) + 1

        if not data:
            summary = {
                'episode': ep_idx,
                'length': 0,
                'total_reward': 0.0,
                'success': False,
                'collision': False,
                'crossing_step': None
            }
        else:
            length = len(data)
            total_reward = sum(step['Reward'] for step in data)

            # 성공: Link 7-1 도달 여부
            success = any(step['Link'] == "7-1" for step in data)

            # 충돌: 보상 기준 혹은 Collision flag 있으면 그걸 써도 됨
            collision = any(step['Reward'] <= -100 for step in data)

            # 교차로 통과 시점
            crossing_step = None
            if success:
                for i, step in enumerate(data):
                    if step['Link'] == "7-1":
                        crossing_step = i + 1   # step index를 1부터 보고 싶으면 +1
                        break

            summary = {
                'episode': ep_idx,
                'length': length,
                'total_reward': float(total_reward),
                'success': bool(success),
                'collision': bool(collision),
                'crossing_step': crossing_step
            }

        self.episode_summaries.append(summary)




    def compute_metrics(self, window_size=1):
        """주요 성능 지표 계산"""
        if not self.episode_data:
            return {}
        recent_episodes = self.episode_data[-window_size:]

        # 1. 성공률 (Link 7 도달)
        successes = [ep for ep in recent_episodes if any(step['Link'] == "7-1" for step in ep)]
        success_rate = len(successes) / len(recent_episodes) if recent_episodes else 0.0
        
        # 2. 충돌률
        collisions = [ep for ep in recent_episodes if any(step['Reward'] <= -100 for step in ep)]
        collision_rate = len(collisions) / len(recent_episodes) if recent_episodes else 0.0
        
        # 3. 평균 에피소드 길이
        episode_lengths = [len(ep) for ep in recent_episodes]
        avg_episode_length = np.mean(episode_lengths) if episode_lengths else 0.0
        
        # 4. 평균 누적 보상
        cumulative_rewards = [sum(step['Reward'] for step in ep) for ep in recent_episodes]
        avg_reward = np.mean(cumulative_rewards) if cumulative_rewards else 0.0
        
        # 5. 교차로 통과 시간 (성공한 경우만)
        crossing_times = []
        for ep in successes:
            for i, step in enumerate(ep):
                if step['Link'] == "7-1":
                    crossing_times.append(i); break
        avg_crossing_time = np.mean(crossing_times) if crossing_times else 0

        metrics = {
            'success_rate': success_rate,
            'collision_rate': collision_rate,
            'avg_episode_length': avg_episode_length,
            'avg_reward': avg_reward,
            'avg_crossing_time': avg_crossing_time
        }

        # 메트릭 저장
        for k, v in metrics.items():
            self.metrics[k].append(v)
        return metrics

    def plot_learning_curves(self):
        """학습 진행 상황 시각화"""
        if not self.metrics:
            return
        
        fig, axes = plt.subplots(2, 2, figsize=(15, 10))
        fig.suptitle('Learning Progress for Intersection Crossing', fontsize=16)

        # 1. 성공률과 충돌률
        ax = axes[0, 0]
        ax.plot(self.metrics['success_rate'], label='Success Rate', color='green')
        ax.plot(self.metrics['collision_rate'], label='Collision Rate', color='red')
        ax.set_title('Success and Collision Rates'); ax.set_xlabel('Evaluation Window'); ax.set_ylabel('Rate'); ax.legend(); ax.grid(True)
        
        # 2. 평균 보상
        ax = axes[0, 1]
        ax.plot(self.metrics['avg_reward'], color='blue')
        ax.set_title('Average Episode Reward'); ax.set_xlabel('Evaluation Window'); ax.set_ylabel('Reward'); ax.grid(True)
        
        # 3. 평균 에피소드 길이
        ax = axes[1, 0]
        ax.plot(self.metrics['avg_episode_length'], color='purple')
        ax.set_title('Average Episode Length'); ax.set_xlabel('Evaluation Window'); ax.set_ylabel('Steps'); ax.grid(True)
        
        # 4. 평균 교차로 통과 시간
        ax = axes[1, 1]
        ax.plot(self.metrics['avg_crossing_time'], color='orange')
        ax.set_title('Average Crossing Time (Successful Episodes)'); ax.set_xlabel('Evaluation Window'); ax.set_ylabel('Steps'); ax.grid(True)
        plt.tight_layout(); plt.show()

    def save_metrics(self, filepath):
        """메트릭 저장"""
        df = pd.DataFrame(self.metrics); df.to_csv(filepath, index=False)

# %%
# =========================
# 메인 (TD3로 학습/평가)
# =========================
# mode="train"
def main(mode='train'):
    # try:

    Network_Path = 'C:/Users/user/2_VISSIM_network/3_IG_RL/Network/rightTurn/'
    inpx_Name    = 'Signal intersection_v5.inpx'
    layx_Name    = 'Signal intersection_v5.layx'

    Vissim = Network(Network_Path, inpx_Name, layx_Name)
    if Vissim is None:
        return


    link_ranges = {1: (10, 30), 2: (100, 150), 3: (10, 30), 4: (100, 150)} # 조정필요

    agent = TD3Agent(
        state_dim=13, 
        act_low=-3.0, 
        act_high=+3.0,
        actor_lr=1.5e-5, 
        critic_lr=1.5e-4,
        gamma=0.99, 
        tau=0.001,
        policy_noise=0.2, 
        noise_clip=0.5,
        policy_delay=2, 
        batch_size=512,
        start_steps=3000, 
        expl_noise=0.2
    )
    monitor = LearningMonitor()
    if mode == 'train':
        n_episodes = 5000
        max_steps  = 2000

        for episode in range(n_episodes):
            try:
                episode_reward = 0.0
                step = 0
                current_episode_data = []
                print(f"--- Episode {episode + 1} Start ---")

                vehicles = None
                for _ in range(3):
                    vehicles = create_vehicles(Vissim, link_ranges)
                    
                    if vehicles:
                        
                        break
                    time.sleep(0.1)
                if not vehicles:
                    print("Failed to create vehicles. Skipping episode.")
                    continue

                ego_vehicle = next((v for v in vehicles if v.AttValue('VehType') == '630'), None)
                print('여긴 ego_vehicle'+str(ego_vehicle.AttValue('No')))
                ego_num = ego_vehicle.AttValue('No')
                # 초기 obs/state
                current_obs = calculate_observations(vehicles, ego_num=ego_num)
                current_state = get_state(vehicles, current_obs, ego_num=ego_num, simsec=Vissim.Simulation.AttValue('SimSec'))

                while step < max_steps:
                    try:
                        vehicles = get_valid_vehicles(Vissim)
                        if not vehicles:
                            break

                        ego_vehicle = next((v for v in vehicles if v.AttValue('VehType') == '630'), None)
                        if ego_vehicle is None:
                            break
                        ego_num = ego_vehicle.AttValue('No')
                        # 최신 obs/state 갱신
                        current_obs = calculate_observations(vehicles, ego_num=ego_num)
                        current_state = get_state(vehicles, current_obs, ego_num=ego_num, simsec=Vissim.Simulation.AttValue('SimSec'))

                        # 행동 선택 및 적용
                        acceleration = agent.select_action(current_state, training=True)
                        apply_action(vehicles, Vissim, acceleration)

                        Vissim.Simulation.RunSingleStep()

                        next_vehicles = get_valid_vehicles(Vissim)
                        if not next_vehicles:
                            break

                        next_obs = calculate_observations(next_vehicles, ego_num=ego_num)
                        next_state = get_state(next_vehicles, next_obs, ego_num=ego_num, simsec=Vissim.Simulation.AttValue('SimSec'))

                        reward, done = get_reward(ego_vehicle, next_obs)
                        if is_episode_done(ego_vehicle, next_obs):
                            done = True

                        episode_reward += float(reward)
                        agent.replay_buffer.push(current_state, acceleration, reward, next_state, done)
                        agent.train_step()

                        step_data = {
                            'Step': step + 1,
                            'Action': acceleration,
                            'Reward': float(reward),
                            'Speed': ego_vehicle.AttValue('Speed'),
                            'Position': ego_vehicle.AttValue('Pos'),
                            'Link': ego_vehicle.AttValue('Lane')
                        }
                        current_episode_data.append(step_data)

                        if done:
                            break
                        step += 1
                        time.sleep(0.05)
                    except Exception as e:
                        print(f"Error in step {step}: {str(e)}")
                        break

                monitor.add_episode_data(current_episode_data)
                print(f"Episode {episode + 1}: Reward = {episode_reward:.2f}, Steps = {step}")


                if (episode + 1) % 100 == 0:
                    metrics = monitor.compute_metrics()
                    print("\nPerformance Metrics:")
                    print(f"Success Rate: {metrics['success_rate']:.2%}")
                    print(f"Collision Rate: {metrics['collision_rate']:.2%}")
                    print(f"Avg Episode Length: {metrics['avg_episode_length']:.1f}")
                    print(f"Avg Reward: {metrics['avg_reward']:.1f}")
                    print(f"Avg Crossing Time: {metrics['avg_crossing_time']:.1f}")
                    monitor.plot_learning_curves()
                    monitor.save_metrics(f'output/v5/training_metrics_toy_3_episode_{episode + 1}.csv')
                    agent.save_models(f'models/v5/checkpoint_{episode + 1}')

            except Exception as e:
                print(f"Error in episode {episode + 1}: {str(e)}")
                continue

            agent.save_models('models/v5/final')
            monitor.save_metrics('output/v5/final_training_metrics_toy3.csv')


    elif mode == 'evaluate':
        agent.load_models('models/v5/final')

    results_df = evaluate(Vissim, agent, link_ranges)
    results_df.to_csv('output/v5/evaluation_results_toy5.csv', index=False)

    # except Exception as e:
    #     print(f"Critical error in main: {str(e)}")
    # finally:
    #     if 'Vissim' in locals():
    #         try:
    #             Vissim.Simulation.Stop()
    #         except:
    #             pass

if __name__ == "__main__":
    main(mode='train')  # 필요 시 'evaluate'
# Out:
# Episode done: Reached target point.
# Episode 3128: Reward = -34.00, Steps = 14
# --- Episode 3129 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3129: Reward = 18.00, Steps = 12
# --- Episode 3130 Start ---
# 여긴 ego_vehicle17
# Episode 3130: Reward = -239.00, Steps = 7
# --- Episode 3131 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3131: Reward = 18.00, Steps = 12
# --- Episode 3132 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3132: Reward = 22.00, Steps = 14
# --- Episode 3133 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 3133: Reward = -24.00, Steps = 14
# --- Episode 3134 Start ---
# 여긴 ego_vehicle13
# Episode done: Reached target point.
# Episode 3134: Reward = -30.00, Steps = 14
# --- Episode 3135 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 3135: Reward = -8.00, Steps = 13
# --- Episode 3136 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 3136: Reward = 28.00, Steps = 13
# --- Episode 3137 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 3137: Reward = 18.00, Steps = 12
# --- Episode 3138 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3138: Reward = 23.00, Steps = 13
# --- Episode 3139 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 3139: Reward = 22.00, Steps = 13
# --- Episode 3140 Start ---
# 여긴 ego_vehicle22
# Episode done: Reached target point.
# Episode 3140: Reward = -54.00, Steps = 14
# --- Episode 3141 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3141: Reward = -36.00, Steps = 15
# --- Episode 3142 Start ---
# 여긴 ego_vehicle22
# Episode done: Reached target point.
# Episode 3142: Reward = 0.00, Steps = 14
# --- Episode 3143 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 3143: Reward = 17.00, Steps = 13
# --- Episode 3144 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 3144: Reward = 22.00, Steps = 13
# --- Episode 3145 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3145: Reward = -16.00, Steps = 13
# --- Episode 3146 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3146: Reward = -4.00, Steps = 13
# --- Episode 3147 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 3147: Reward = -12.00, Steps = 13
# --- Episode 3148 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 3148: Reward = -2.00, Steps = 14
# --- Episode 3149 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3149: Reward = 16.00, Steps = 14
# --- Episode 3150 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 3150: Reward = -46.00, Steps = 13
# --- Episode 3151 Start ---
# 여긴 ego_vehicle28
# Episode done: Reached target point.
# Episode 3151: Reward = 12.00, Steps = 13
# --- Episode 3152 Start ---
# 여긴 ego_vehicle23
# Episode done: Reached target point.
# Episode 3152: Reward = 24.00, Steps = 14
# --- Episode 3153 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3153: Reward = -44.00, Steps = 14
# --- Episode 3154 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 3154: Reward = -30.00, Steps = 14
# --- Episode 3155 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3155: Reward = 22.00, Steps = 13
# --- Episode 3156 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 3156: Reward = -30.00, Steps = 13
# --- Episode 3157 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 3157: Reward = 17.00, Steps = 15
# --- Episode 3158 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 3158: Reward = -18.00, Steps = 13
# --- Episode 3159 Start ---
# 여긴 ego_vehicle23
# Episode done: Reached target point.
# Episode 3159: Reward = -2.00, Steps = 14
# --- Episode 3160 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3160: Reward = 13.00, Steps = 13
# --- Episode 3161 Start ---
# 여긴 ego_vehicle13
# Episode done: Reached target point.
# Episode 3161: Reward = 16.00, Steps = 13
# --- Episode 3162 Start ---
# 여긴 ego_vehicle12
# Episode done: Reached target point.
# Episode 3162: Reward = 28.00, Steps = 13
# --- Episode 3163 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 3163: Reward = 16.00, Steps = 13
# --- Episode 3164 Start ---
# 여긴 ego_vehicle23
# Episode done: Reached target point.
# Episode 3164: Reward = -28.00, Steps = 14
# --- Episode 3165 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 3165: Reward = -14.00, Steps = 13
# --- Episode 3166 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3166: Reward = 28.00, Steps = 13
# --- Episode 3167 Start ---
# 여긴 ego_vehicle24
# Episode done: Reached target point.
# Episode 3167: Reward = -7.00, Steps = 12
# --- Episode 3168 Start ---
# 여긴 ego_vehicle18
# Episode 3168: Reward = -217.00, Steps = 11
# --- Episode 3169 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 3169: Reward = 10.00, Steps = 14
# --- Episode 3170 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3170: Reward = 16.00, Steps = 13
# --- Episode 3171 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 3171: Reward = -12.00, Steps = 13
# --- Episode 3172 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 3172: Reward = 21.00, Steps = 12
# --- Episode 3173 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3173: Reward = 28.00, Steps = 13
# --- Episode 3174 Start ---
# 여긴 ego_vehicle8
# Episode done: Reached target point.
# Episode 3174: Reward = 28.00, Steps = 13
# --- Episode 3175 Start ---
# 여긴 ego_vehicle13
# Episode done: Reached target point.
# Episode 3175: Reward = 20.00, Steps = 12
# --- Episode 3176 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 3176: Reward = -22.00, Steps = 14
# --- Episode 3177 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 3177: Reward = 28.00, Steps = 13
# --- Episode 3178 Start ---
# 여긴 ego_vehicle18
# Episode 3178: Reward = -229.00, Steps = 8
# --- Episode 3179 Start ---
# 여긴 ego_vehicle12
# Episode done: Reached target point.
# Episode 3179: Reward = -30.00, Steps = 14
# --- Episode 3180 Start ---
# 여긴 ego_vehicle28
# Episode done: Reached target point.
# Episode 3180: Reward = 24.00, Steps = 13
# --- Episode 3181 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3181: Reward = -8.00, Steps = 14
# --- Episode 3182 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 3182: Reward = 30.00, Steps = 14
# --- Episode 3183 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 3183: Reward = -10.00, Steps = 14
# --- Episode 3184 Start ---
# 여긴 ego_vehicle9
# Episode done: Reached target point.
# Episode 3184: Reward = 16.00, Steps = 12
# --- Episode 3185 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3185: Reward = 22.00, Steps = 13
# --- Episode 3186 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3186: Reward = 1.00, Steps = 12
# --- Episode 3187 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 3187: Reward = -12.00, Steps = 14
# --- Episode 3188 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 3188: Reward = 22.00, Steps = 12
# --- Episode 3189 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3189: Reward = -55.00, Steps = 16
# --- Episode 3190 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 3190: Reward = -44.00, Steps = 13
# --- Episode 3191 Start ---
# 여긴 ego_vehicle22
# Episode done: Reached target point.
# Episode 3191: Reward = -48.00, Steps = 15
# --- Episode 3192 Start ---
# 여긴 ego_vehicle23
# Episode done: Reached target point.
# Episode 3192: Reward = -5.00, Steps = 14
# --- Episode 3193 Start ---
# 여긴 ego_vehicle17
# Episode 3193: Reward = -199.00, Steps = 11
# --- Episode 3194 Start ---
# 여긴 ego_vehicle22
# Episode 3194: Reward = -208.00, Steps = 12
# --- Episode 3195 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 3195: Reward = 28.00, Steps = 13
# --- Episode 3196 Start ---
# 여긴 ego_vehicle25
# Episode done: Reached target point.
# Episode 3196: Reward = 22.00, Steps = 14
# --- Episode 3197 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 3197: Reward = 15.00, Steps = 13
# --- Episode 3198 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 3198: Reward = 28.00, Steps = 13
# --- Episode 3199 Start ---
# 여긴 ego_vehicle22
# Episode done: Reached target point.
# Episode 3199: Reward = 28.00, Steps = 13
# --- Episode 3200 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3200: Reward = 28.00, Steps = 13
#
# Performance Metrics:
# Success Rate: 100.00%
# Collision Rate: 0.00%
# Avg Episode Length: 14.0
# Avg Reward: 28.0
# Avg Crossing Time: 11.0
# --- Episode 3201 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3201: Reward = 16.00, Steps = 13
# --- Episode 3202 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3202: Reward = -20.00, Steps = 13
# --- Episode 3203 Start ---
# 여긴 ego_vehicle22
# Episode 3203: Reward = -217.00, Steps = 8
# --- Episode 3204 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3204: Reward = 16.00, Steps = 12
# --- Episode 3205 Start ---
# 여긴 ego_vehicle12
# Episode done: Reached target point.
# Episode 3205: Reward = 30.00, Steps = 14
# --- Episode 3206 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 3206: Reward = 15.00, Steps = 13
# --- Episode 3207 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 3207: Reward = 16.00, Steps = 14
# --- Episode 3208 Start ---
# 여긴 ego_vehicle22
# Episode done: Reached target point.
# Episode 3208: Reward = -16.00, Steps = 14
# --- Episode 3209 Start ---
# 여긴 ego_vehicle23
# Episode done: Reached target point.
# Episode 3209: Reward = 18.00, Steps = 13
# --- Episode 3210 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3210: Reward = -16.00, Steps = 15
# --- Episode 3211 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3211: Reward = -4.00, Steps = 13
# --- Episode 3212 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3212: Reward = 16.00, Steps = 12
# --- Episode 3213 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 3213: Reward = 7.00, Steps = 13
# --- Episode 3214 Start ---
# 여긴 ego_vehicle12
# Episode done: Reached target point.
# Episode 3214: Reward = 16.00, Steps = 12
# --- Episode 3215 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3215: Reward = -32.00, Steps = 14
# --- Episode 3216 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 3216: Reward = -62.00, Steps = 13
# --- Episode 3217 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 3217: Reward = 22.00, Steps = 13
# --- Episode 3218 Start ---
# 여긴 ego_vehicle25
# Episode done: Reached target point.
# Episode 3218: Reward = 22.00, Steps = 13
# --- Episode 3219 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3219: Reward = -8.00, Steps = 14
# --- Episode 3220 Start ---
# 여긴 ego_vehicle22
# Episode done: Reached target point.
# Episode 3220: Reward = -15.00, Steps = 12
# --- Episode 3221 Start ---
# 여긴 ego_vehicle25
# Episode done: Reached target point.
# Episode 3221: Reward = -14.00, Steps = 14
# --- Episode 3222 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 3222: Reward = 22.00, Steps = 13
# --- Episode 3223 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3223: Reward = -14.00, Steps = 14
# --- Episode 3224 Start ---
# 여긴 ego_vehicle23
# Episode 3224: Reward = -209.00, Steps = 10
# --- Episode 3225 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 3225: Reward = 28.00, Steps = 13
# --- Episode 3226 Start ---
# 여긴 ego_vehicle13
# Episode done: Reached target point.
# Episode 3226: Reward = -4.00, Steps = 13
# --- Episode 3227 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 3227: Reward = -14.00, Steps = 13
# --- Episode 3228 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3228: Reward = 4.00, Steps = 13
# --- Episode 3229 Start ---
# 여긴 ego_vehicle12
# Episode done: Reached target point.
# Episode 3229: Reward = 28.00, Steps = 13
# --- Episode 3230 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 3230: Reward = 16.00, Steps = 14
# --- Episode 3231 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 3231: Reward = -26.00, Steps = 14
# --- Episode 3232 Start ---
# 여긴 ego_vehicle22
# Episode done: Reached target point.
# Episode 3232: Reward = -8.00, Steps = 15
# --- Episode 3233 Start ---
# 여긴 ego_vehicle23
# Episode done: Reached target point.
# Episode 3233: Reward = -28.00, Steps = 14
# --- Episode 3234 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3234: Reward = 2.00, Steps = 13
# --- Episode 3235 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3235: Reward = 15.00, Steps = 12
# --- Episode 3236 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3236: Reward = 4.00, Steps = 12
# --- Episode 3237 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3237: Reward = -20.00, Steps = 16
# --- Episode 3238 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3238: Reward = 26.00, Steps = 13
# --- Episode 3239 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3239: Reward = 30.00, Steps = 14
# --- Episode 3240 Start ---
# 여긴 ego_vehicle13
# Episode done: Reached target point.
# Episode 3240: Reward = -14.00, Steps = 13
# --- Episode 3241 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3241: Reward = -16.00, Steps = 13
# --- Episode 3242 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3242: Reward = -12.00, Steps = 13
# --- Episode 3243 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3243: Reward = 9.00, Steps = 16
# --- Episode 3244 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3244: Reward = 18.00, Steps = 13
# --- Episode 3245 Start ---
# 여긴 ego_vehicle22
# Episode done: Reached target point.
# Episode 3245: Reward = -22.00, Steps = 14
# --- Episode 3246 Start ---
# 여긴 ego_vehicle12
# Episode done: Reached target point.
# Episode 3246: Reward = 28.00, Steps = 13
# --- Episode 3247 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3247: Reward = 28.00, Steps = 14
# --- Episode 3248 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3248: Reward = -20.00, Steps = 16
# --- Episode 3249 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 3249: Reward = 21.00, Steps = 13
# --- Episode 3250 Start ---
# 여긴 ego_vehicle17
# Episode 3250: Reward = -177.00, Steps = 11
# --- Episode 3251 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 3251: Reward = 28.00, Steps = 13
# --- Episode 3252 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3252: Reward = 28.00, Steps = 13
# --- Episode 3253 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3253: Reward = -6.00, Steps = 14
# --- Episode 3254 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3254: Reward = 26.00, Steps = 12
# --- Episode 3255 Start ---
# 여긴 ego_vehicle13
# Episode done: Reached target point.
# Episode 3255: Reward = 30.00, Steps = 14
# --- Episode 3256 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 3256: Reward = 2.00, Steps = 14
# --- Episode 3257 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 3257: Reward = 18.00, Steps = 16
# --- Episode 3258 Start ---
# 여긴 ego_vehicle22
# Episode done: Reached target point.
# Episode 3258: Reward = 14.00, Steps = 13
# --- Episode 3259 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3259: Reward = 6.00, Steps = 15
# --- Episode 3260 Start ---
# 여긴 ego_vehicle19
# Episode 3260: Reward = -254.00, Steps = 10
# --- Episode 3261 Start ---
# 여긴 ego_vehicle23
# Episode done: Reached target point.
# Episode 3261: Reward = 17.00, Steps = 12
# --- Episode 3262 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 3262: Reward = 28.00, Steps = 13
# --- Episode 3263 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3263: Reward = -24.00, Steps = 13
# --- Episode 3264 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3264: Reward = 4.00, Steps = 13
# --- Episode 3265 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3265: Reward = 28.00, Steps = 13
# --- Episode 3266 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 3266: Reward = 30.00, Steps = 14
# --- Episode 3267 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 3267: Reward = 13.00, Steps = 13
# --- Episode 3268 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3268: Reward = 28.00, Steps = 13
# --- Episode 3269 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 3269: Reward = 24.00, Steps = 13
# --- Episode 3270 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3270: Reward = 22.00, Steps = 13
# --- Episode 3271 Start ---
# 여긴 ego_vehicle12
# Episode done: Reached target point.
# Episode 3271: Reward = -26.00, Steps = 13
# --- Episode 3272 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 3272: Reward = 28.00, Steps = 13
# --- Episode 3273 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 3273: Reward = -2.00, Steps = 14
# --- Episode 3274 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3274: Reward = 28.00, Steps = 13
# --- Episode 3275 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3275: Reward = -12.00, Steps = 13
# --- Episode 3276 Start ---
# 여긴 ego_vehicle13
# Episode done: Reached target point.
# Episode 3276: Reward = 16.00, Steps = 13
# --- Episode 3277 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3277: Reward = 16.00, Steps = 13
# --- Episode 3278 Start ---
# 여긴 ego_vehicle22
# Episode done: Reached target point.
# Episode 3278: Reward = -8.00, Steps = 14
# --- Episode 3279 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 3279: Reward = -4.00, Steps = 13
# --- Episode 3280 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 3280: Reward = 18.00, Steps = 14
# --- Episode 3281 Start ---
# 여긴 ego_vehicle23
# Episode done: Reached target point.
# Episode 3281: Reward = -22.00, Steps = 13
# --- Episode 3282 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3282: Reward = -4.00, Steps = 13
# --- Episode 3283 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3283: Reward = -60.00, Steps = 14
# --- Episode 3284 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3284: Reward = -24.00, Steps = 13
# --- Episode 3285 Start ---
# 여긴 ego_vehicle13
# Episode done: Reached target point.
# Episode 3285: Reward = 22.00, Steps = 15
# --- Episode 3286 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 3286: Reward = -4.00, Steps = 13
# --- Episode 3287 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 3287: Reward = -3.00, Steps = 12
# --- Episode 3288 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3288: Reward = -4.00, Steps = 13
# --- Episode 3289 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3289: Reward = 16.00, Steps = 12
# --- Episode 3290 Start ---
# 여긴 ego_vehicle21
# Episode 3290: Reward = -237.00, Steps = 8
# --- Episode 3291 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 3291: Reward = 26.00, Steps = 13
# --- Episode 3292 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3292: Reward = 28.00, Steps = 13
# --- Episode 3293 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 3293: Reward = -18.00, Steps = 13
# --- Episode 3294 Start ---
# 여긴 ego_vehicle25
# Episode done: Reached target point.
# Episode 3294: Reward = -4.00, Steps = 14
# --- Episode 3295 Start ---
# 여긴 ego_vehicle22
# Episode done: Reached target point.
# Episode 3295: Reward = -16.00, Steps = 13
# --- Episode 3296 Start ---
# 여긴 ego_vehicle20
# Episode 3296: Reward = -239.00, Steps = 7
# --- Episode 3297 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3297: Reward = 21.00, Steps = 13
# --- Episode 3298 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3298: Reward = 6.00, Steps = 13
# --- Episode 3299 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 3299: Reward = 16.00, Steps = 13
# --- Episode 3300 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 3300: Reward = 9.00, Steps = 12
#
# Performance Metrics:
# Success Rate: 100.00%
# Collision Rate: 0.00%
# Avg Episode Length: 13.0
# Avg Reward: 9.0
# Avg Crossing Time: 10.0
# --- Episode 3301 Start ---
# 여긴 ego_vehicle13
# Episode done: Reached target point.
# Episode 3301: Reward = 28.00, Steps = 13
# --- Episode 3302 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 3302: Reward = -33.00, Steps = 16
# --- Episode 3303 Start ---
# 여긴 ego_vehicle23
# Episode done: Reached target point.
# Episode 3303: Reward = -38.00, Steps = 13
# --- Episode 3304 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 3304: Reward = 30.00, Steps = 14
# --- Episode 3305 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 3305: Reward = -14.00, Steps = 13
# --- Episode 3306 Start ---
# 여긴 ego_vehicle23
# Episode done: Reached target point.
# Episode 3306: Reward = -16.00, Steps = 14
# --- Episode 3307 Start ---
# 여긴 ego_vehicle21
# Episode 3307: Reward = -209.00, Steps = 11
# --- Episode 3308 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3308: Reward = -26.00, Steps = 14
# --- Episode 3309 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 3309: Reward = 20.00, Steps = 13
# --- Episode 3310 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3310: Reward = 20.00, Steps = 14
# --- Episode 3311 Start ---
# 여긴 ego_vehicle12
# Episode done: Reached target point.
# Episode 3311: Reward = 15.00, Steps = 12
# --- Episode 3312 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3312: Reward = 28.00, Steps = 13
# --- Episode 3313 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3313: Reward = -16.00, Steps = 13
# --- Episode 3314 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3314: Reward = 10.00, Steps = 15
# --- Episode 3315 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 3315: Reward = -10.00, Steps = 15
# --- Episode 3316 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 3316: Reward = -12.00, Steps = 14
# --- Episode 3317 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 3317: Reward = -37.00, Steps = 14
# --- Episode 3318 Start ---
# 여긴 ego_vehicle25
# Episode done: Reached target point.
# Episode 3318: Reward = -18.00, Steps = 14
# --- Episode 3319 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3319: Reward = 28.00, Steps = 13
# --- Episode 3320 Start ---
# 여긴 ego_vehicle8
# Episode done: Reached target point.
# Episode 3320: Reward = 28.00, Steps = 13
# --- Episode 3321 Start ---
# 여긴 ego_vehicle13
# Episode done: Reached target point.
# Episode 3321: Reward = 11.00, Steps = 12
# --- Episode 3322 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 3322: Reward = -34.00, Steps = 14
# --- Episode 3323 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3323: Reward = 16.00, Steps = 13
# --- Episode 3324 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 3324: Reward = 28.00, Steps = 13
# --- Episode 3325 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3325: Reward = 26.00, Steps = 13
# --- Episode 3326 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3326: Reward = -4.00, Steps = 14
# --- Episode 3327 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 3327: Reward = -4.00, Steps = 13
# --- Episode 3328 Start ---
# 여긴 ego_vehicle12
# Episode done: Reached target point.
# Episode 3328: Reward = -32.00, Steps = 13
# --- Episode 3329 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 3329: Reward = -6.00, Steps = 13
# --- Episode 3330 Start ---
# 여긴 ego_vehicle28
# Episode done: Reached target point.
# Episode 3330: Reward = 24.00, Steps = 13
# --- Episode 3331 Start ---
# 여긴 ego_vehicle25
# Episode done: Reached target point.
# Episode 3331: Reward = -11.00, Steps = 12
# --- Episode 3332 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3332: Reward = 28.00, Steps = 13
# --- Episode 3333 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 3333: Reward = 30.00, Steps = 14
# --- Episode 3334 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 3334: Reward = 12.00, Steps = 14
# --- Episode 3335 Start ---
# 여긴 ego_vehicle12
# Episode done: Reached target point.
# Episode 3335: Reward = -20.00, Steps = 13
# --- Episode 3336 Start ---
# 여긴 ego_vehicle23
# Episode done: Reached target point.
# Episode 3336: Reward = -19.00, Steps = 16
# --- Episode 3337 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 3337: Reward = 20.00, Steps = 14
# --- Episode 3338 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3338: Reward = 28.00, Steps = 13
# --- Episode 3339 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 3339: Reward = -14.00, Steps = 14
# --- Episode 3340 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3340: Reward = 16.00, Steps = 12
# --- Episode 3341 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 3341: Reward = -14.00, Steps = 13
# --- Episode 3342 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 3342: Reward = 12.00, Steps = 15
# --- Episode 3343 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3343: Reward = 17.00, Steps = 13
# --- Episode 3344 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3344: Reward = -15.00, Steps = 13
# --- Episode 3345 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 3345: Reward = 9.00, Steps = 13
# --- Episode 3346 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 3346: Reward = 4.00, Steps = 14
# --- Episode 3347 Start ---
# 여긴 ego_vehicle21
# Episode 3347: Reward = -191.00, Steps = 11
# --- Episode 3348 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3348: Reward = 22.00, Steps = 13
# --- Episode 3349 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3349: Reward = 16.00, Steps = 14
# --- Episode 3350 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 3350: Reward = -20.00, Steps = 14
# --- Episode 3351 Start ---
# 여긴 ego_vehicle24
# Episode done: Reached target point.
# Episode 3351: Reward = -2.00, Steps = 12
# --- Episode 3352 Start ---
# 여긴 ego_vehicle22
# Episode done: Reached target point.
# Episode 3352: Reward = -10.00, Steps = 13
# --- Episode 3353 Start ---
# 여긴 ego_vehicle8
# Episode done: Reached target point.
# Episode 3353: Reward = 28.00, Steps = 13
# --- Episode 3354 Start ---
# 여긴 ego_vehicle12
# Episode done: Reached target point.
# Episode 3354: Reward = 19.00, Steps = 13
# --- Episode 3355 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3355: Reward = 28.00, Steps = 13
# --- Episode 3356 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 3356: Reward = 9.00, Steps = 12
# --- Episode 3357 Start ---
# 여긴 ego_vehicle13
# Episode done: Reached target point.
# Episode 3357: Reward = 2.00, Steps = 14
# --- Episode 3358 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 3358: Reward = -4.00, Steps = 14
# --- Episode 3359 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3359: Reward = 28.00, Steps = 13
# --- Episode 3360 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3360: Reward = 28.00, Steps = 13
# --- Episode 3361 Start ---
# 여긴 ego_vehicle21
# Episode 3361: Reward = -219.00, Steps = 11
# --- Episode 3362 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 3362: Reward = 6.00, Steps = 12
# --- Episode 3363 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3363: Reward = -45.00, Steps = 15
# --- Episode 3364 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 3364: Reward = -18.00, Steps = 13
# --- Episode 3365 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 3365: Reward = -10.00, Steps = 14
# --- Episode 3366 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 3366: Reward = -8.00, Steps = 13
# --- Episode 3367 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3367: Reward = -36.00, Steps = 15
# --- Episode 3368 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3368: Reward = 16.00, Steps = 13
# --- Episode 3369 Start ---
# 여긴 ego_vehicle24
# Episode done: Reached target point.
# Episode 3369: Reward = -36.00, Steps = 14
# --- Episode 3370 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 3370: Reward = 28.00, Steps = 13
# --- Episode 3371 Start ---
# 여긴 ego_vehicle15
# Episode 3371: Reward = -229.00, Steps = 10
# --- Episode 3372 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 3372: Reward = 6.00, Steps = 13
# --- Episode 3373 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3373: Reward = 14.00, Steps = 13
# --- Episode 3374 Start ---
# 여긴 ego_vehicle12
# Episode done: Reached target point.
# Episode 3374: Reward = 22.00, Steps = 13
# --- Episode 3375 Start ---
# 여긴 ego_vehicle18
# Episode 3375: Reward = -229.00, Steps = 8
# --- Episode 3376 Start ---
# 여긴 ego_vehicle17
# Episode 3376: Reward = -215.00, Steps = 8
# --- Episode 3377 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3377: Reward = -38.00, Steps = 14
# --- Episode 3378 Start ---
# 여긴 ego_vehicle23
# Episode done: Reached target point.
# Episode 3378: Reward = 28.00, Steps = 13
# --- Episode 3379 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3379: Reward = 22.00, Steps = 13
# --- Episode 3380 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 3380: Reward = 20.00, Steps = 13
# --- Episode 3381 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 3381: Reward = 28.00, Steps = 13
# --- Episode 3382 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3382: Reward = 28.00, Steps = 13
# --- Episode 3383 Start ---
# 여긴 ego_vehicle11
# Episode done: Reached target point.
# Episode 3383: Reward = 28.00, Steps = 13
# --- Episode 3384 Start ---
# 여긴 ego_vehicle11
# Episode 3384: Reward = -207.00, Steps = 11
# --- Episode 3385 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3385: Reward = -24.00, Steps = 14
# --- Episode 3386 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 3386: Reward = -7.00, Steps = 15
# --- Episode 3387 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 3387: Reward = -4.00, Steps = 13
# --- Episode 3388 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 3388: Reward = 28.00, Steps = 14
# --- Episode 3389 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 3389: Reward = 18.00, Steps = 13
# --- Episode 3390 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3390: Reward = -10.00, Steps = 14
# --- Episode 3391 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 3391: Reward = 18.00, Steps = 14
# --- Episode 3392 Start ---
# 여긴 ego_vehicle13
# Episode done: Reached target point.
# Episode 3392: Reward = 19.00, Steps = 12
# --- Episode 3393 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 3393: Reward = -12.00, Steps = 13
# --- Episode 3394 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 3394: Reward = -4.00, Steps = 13
# --- Episode 3395 Start ---
# 여긴 ego_vehicle16
# Episode 3395: Reward = -219.00, Steps = 7
# --- Episode 3396 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3396: Reward = 20.00, Steps = 13
# --- Episode 3397 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 3397: Reward = 28.00, Steps = 13
# --- Episode 3398 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 3398: Reward = -18.00, Steps = 14
# --- Episode 3399 Start ---
# 여긴 ego_vehicle12
# Episode done: Reached target point.
# Episode 3399: Reward = -34.00, Steps = 14
# --- Episode 3400 Start ---
# 여긴 ego_vehicle22
# Episode done: Reached target point.
# Episode 3400: Reward = 26.00, Steps = 14
#
# Performance Metrics:
# Success Rate: 100.00%
# Collision Rate: 0.00%
# Avg Episode Length: 15.0
# Avg Reward: 26.0
# Avg Crossing Time: 11.0
# --- Episode 3401 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 3401: Reward = -22.00, Steps = 14
# --- Episode 3402 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3402: Reward = 28.00, Steps = 13
# --- Episode 3403 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3403: Reward = 21.00, Steps = 13
# --- Episode 3404 Start ---
# 여긴 ego_vehicle24
# Episode done: Reached target point.
# Episode 3404: Reward = 28.00, Steps = 13
# --- Episode 3405 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3405: Reward = -34.00, Steps = 14
# --- Episode 3406 Start ---
# 여긴 ego_vehicle12
# Episode done: Reached target point.
# Episode 3406: Reward = 28.00, Steps = 13
# --- Episode 3407 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3407: Reward = 27.00, Steps = 13
# --- Episode 3408 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3408: Reward = 28.00, Steps = 13
# --- Episode 3409 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 3409: Reward = 21.00, Steps = 16
# --- Episode 3410 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 3410: Reward = 16.00, Steps = 13
# --- Episode 3411 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3411: Reward = 28.00, Steps = 13
# --- Episode 3412 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 3412: Reward = -38.00, Steps = 15
# --- Episode 3413 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 3413: Reward = -22.00, Steps = 13
# --- Episode 3414 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 3414: Reward = 28.00, Steps = 13
# --- Episode 3415 Start ---
# 여긴 ego_vehicle22
# Episode done: Reached target point.
# Episode 3415: Reward = -34.00, Steps = 14
# --- Episode 3416 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 3416: Reward = 28.00, Steps = 13
# --- Episode 3417 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 3417: Reward = 8.00, Steps = 14
# --- Episode 3418 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3418: Reward = -12.00, Steps = 14
# --- Episode 3419 Start ---
# 여긴 ego_vehicle12
# Episode done: Reached target point.
# Episode 3419: Reward = -32.00, Steps = 13
# --- Episode 3420 Start ---
# 여긴 ego_vehicle13
# Episode done: Reached target point.
# Episode 3420: Reward = 2.00, Steps = 14
# --- Episode 3421 Start ---
# 여긴 ego_vehicle26
# Episode done: Reached target point.
# Episode 3421: Reward = -33.00, Steps = 13
# --- Episode 3422 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 3422: Reward = 28.00, Steps = 13
# --- Episode 3423 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3423: Reward = -12.00, Steps = 13
# --- Episode 3424 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 3424: Reward = -14.00, Steps = 15
# --- Episode 3425 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3425: Reward = 24.00, Steps = 14
# --- Episode 3426 Start ---
# 여긴 ego_vehicle12
# Episode done: Reached target point.
# Episode 3426: Reward = 28.00, Steps = 13
# --- Episode 3427 Start ---
# 여긴 ego_vehicle22
# Episode done: Reached target point.
# Episode 3427: Reward = 18.00, Steps = 13
# --- Episode 3428 Start ---
# 여긴 ego_vehicle8
# Episode done: Reached target point.
# Episode 3428: Reward = 20.00, Steps = 14
# --- Episode 3429 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3429: Reward = -14.00, Steps = 14
# --- Episode 3430 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 3430: Reward = -14.00, Steps = 13
# --- Episode 3431 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3431: Reward = 28.00, Steps = 13
# --- Episode 3432 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 3432: Reward = -44.00, Steps = 16
# --- Episode 3433 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3433: Reward = -26.00, Steps = 13
# --- Episode 3434 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 3434: Reward = 28.00, Steps = 13
# --- Episode 3435 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 3435: Reward = 14.00, Steps = 13
# --- Episode 3436 Start ---
# 여긴 ego_vehicle24
# Episode done: Reached target point.
# Episode 3436: Reward = 7.00, Steps = 13
# --- Episode 3437 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3437: Reward = 18.00, Steps = 13
# --- Episode 3438 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3438: Reward = -23.00, Steps = 16
# --- Episode 3439 Start ---
# 여긴 ego_vehicle23
# Episode done: Reached target point.
# Episode 3439: Reward = -38.00, Steps = 13
# --- Episode 3440 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3440: Reward = 28.00, Steps = 13
# --- Episode 3441 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3441: Reward = -13.00, Steps = 13
# --- Episode 3442 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 3442: Reward = 28.00, Steps = 13
# --- Episode 3443 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 3443: Reward = -46.00, Steps = 13
# --- Episode 3444 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3444: Reward = -12.00, Steps = 13
# --- Episode 3445 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3445: Reward = 28.00, Steps = 13
# --- Episode 3446 Start ---
# 여긴 ego_vehicle13
# Episode done: Reached target point.
# Episode 3446: Reward = 22.00, Steps = 14
# --- Episode 3447 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 3447: Reward = 1.00, Steps = 15
# --- Episode 3448 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 3448: Reward = 28.00, Steps = 13
# --- Episode 3449 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 3449: Reward = -32.00, Steps = 14
# --- Episode 3450 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3450: Reward = 10.00, Steps = 14
# --- Episode 3451 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3451: Reward = 12.00, Steps = 13
# --- Episode 3452 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 3452: Reward = -2.00, Steps = 13
# --- Episode 3453 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3453: Reward = -26.00, Steps = 14
# --- Episode 3454 Start ---
# 여긴 ego_vehicle13
# Episode done: Reached target point.
# Episode 3454: Reward = -14.00, Steps = 13
# --- Episode 3455 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 3455: Reward = 24.00, Steps = 13
# --- Episode 3456 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 3456: Reward = -15.00, Steps = 13
# --- Episode 3457 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 3457: Reward = 16.00, Steps = 13
# --- Episode 3458 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3458: Reward = 14.00, Steps = 13
# --- Episode 3459 Start ---
# 여긴 ego_vehicle12
# Episode done: Reached target point.
# Episode 3459: Reward = 28.00, Steps = 13
# --- Episode 3460 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3460: Reward = -22.00, Steps = 14
# --- Episode 3461 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 3461: Reward = -2.00, Steps = 15
# --- Episode 3462 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3462: Reward = 20.00, Steps = 14
# --- Episode 3463 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3463: Reward = 2.00, Steps = 13
# --- Episode 3464 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 3464: Reward = -14.00, Steps = 14
# --- Episode 3465 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 3465: Reward = 28.00, Steps = 13
# --- Episode 3466 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3466: Reward = -65.00, Steps = 16
# --- Episode 3467 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3467: Reward = 16.00, Steps = 12
# --- Episode 3468 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3468: Reward = 28.00, Steps = 13
# --- Episode 3469 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3469: Reward = 19.00, Steps = 13
# --- Episode 3470 Start ---
# 여긴 ego_vehicle22
# Episode done: Reached target point.
# Episode 3470: Reward = -18.00, Steps = 13
# --- Episode 3471 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 3471: Reward = -20.00, Steps = 13
# --- Episode 3472 Start ---
# 여긴 ego_vehicle13
# Episode done: Reached target point.
# Episode 3472: Reward = -14.00, Steps = 13
# --- Episode 3473 Start ---
# 여긴 ego_vehicle23
# Episode done: Reached target point.
# Episode 3473: Reward = -12.00, Steps = 14
# --- Episode 3474 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3474: Reward = -18.00, Steps = 14
# --- Episode 3475 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3475: Reward = 12.00, Steps = 13
# --- Episode 3476 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 3476: Reward = 28.00, Steps = 13
# --- Episode 3477 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 3477: Reward = -15.00, Steps = 13
# --- Episode 3478 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3478: Reward = 14.00, Steps = 14
# --- Episode 3479 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 3479: Reward = -12.00, Steps = 13
# --- Episode 3480 Start ---
# 여긴 ego_vehicle23
# Episode 3480: Reward = -186.00, Steps = 11
# --- Episode 3481 Start ---
# 여긴 ego_vehicle22
# Episode done: Reached target point.
# Episode 3481: Reward = -8.00, Steps = 14
# --- Episode 3482 Start ---
# 여긴 ego_vehicle24
# Episode done: Reached target point.
# Episode 3482: Reward = -12.00, Steps = 13
# --- Episode 3483 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 3483: Reward = -22.00, Steps = 13
# --- Episode 3484 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 3484: Reward = 6.00, Steps = 13
# --- Episode 3485 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 3485: Reward = -18.00, Steps = 12
# --- Episode 3486 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3486: Reward = 28.00, Steps = 14
# --- Episode 3487 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3487: Reward = -14.00, Steps = 14
# --- Episode 3488 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 3488: Reward = 28.00, Steps = 13
# --- Episode 3489 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 3489: Reward = -59.00, Steps = 13
# --- Episode 3490 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 3490: Reward = -10.00, Steps = 13
# --- Episode 3491 Start ---
# 여긴 ego_vehicle22
# Episode done: Reached target point.
# Episode 3491: Reward = -22.00, Steps = 14
# --- Episode 3492 Start ---
# 여긴 ego_vehicle13
# Episode done: Reached target point.
# Episode 3492: Reward = -32.00, Steps = 14
# --- Episode 3493 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 3493: Reward = -14.00, Steps = 14
# --- Episode 3494 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3494: Reward = -14.00, Steps = 14
# --- Episode 3495 Start ---
# 여긴 ego_vehicle23
# Episode 3495: Reward = -213.00, Steps = 11
# --- Episode 3496 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3496: Reward = -10.00, Steps = 14
# --- Episode 3497 Start ---
# 여긴 ego_vehicle23
# Episode done: Reached target point.
# Episode 3497: Reward = -14.00, Steps = 15
# --- Episode 3498 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3498: Reward = 14.00, Steps = 14
# --- Episode 3499 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 3499: Reward = -8.00, Steps = 13
# --- Episode 3500 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3500: Reward = 26.00, Steps = 13
#
# Performance Metrics:
# Success Rate: 100.00%
# Collision Rate: 0.00%
# Avg Episode Length: 14.0
# Avg Reward: 26.0
# Avg Crossing Time: 11.0
# --- Episode 3501 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 3501: Reward = 28.00, Steps = 13
# --- Episode 3502 Start ---
# 여긴 ego_vehicle22
# Episode done: Reached target point.
# Episode 3502: Reward = 18.00, Steps = 13
# --- Episode 3503 Start ---
# 여긴 ego_vehicle17
# Episode 3503: Reward = -177.00, Steps = 11
# --- Episode 3504 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3504: Reward = 30.00, Steps = 14
# --- Episode 3505 Start ---
# 여긴 ego_vehicle23
# Episode done: Reached target point.
# Episode 3505: Reward = -11.00, Steps = 12
# --- Episode 3506 Start ---
# 여긴 ego_vehicle22
# Episode done: Reached target point.
# Episode 3506: Reward = -4.00, Steps = 15
# --- Episode 3507 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 3507: Reward = 24.00, Steps = 13
# --- Episode 3508 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 3508: Reward = 16.00, Steps = 12
# --- Episode 3509 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 3509: Reward = 16.00, Steps = 14
# --- Episode 3510 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 3510: Reward = 20.00, Steps = 14
# --- Episode 3511 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3511: Reward = -51.00, Steps = 21
# --- Episode 3512 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 3512: Reward = -4.00, Steps = 13
# --- Episode 3513 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 3513: Reward = -16.00, Steps = 13
# --- Episode 3514 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3514: Reward = 28.00, Steps = 14
# --- Episode 3515 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3515: Reward = 28.00, Steps = 13
# --- Episode 3516 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 3516: Reward = 18.00, Steps = 13
# --- Episode 3517 Start ---
# 여긴 ego_vehicle13
# Episode done: Reached target point.
# Episode 3517: Reward = 28.00, Steps = 13
# --- Episode 3518 Start ---
# 여긴 ego_vehicle22
# Episode done: Reached target point.
# Episode 3518: Reward = -4.00, Steps = 13
# --- Episode 3519 Start ---
# 여긴 ego_vehicle22
# Episode done: Reached target point.
# Episode 3519: Reward = 28.00, Steps = 13
# --- Episode 3520 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3520: Reward = -6.00, Steps = 14
# --- Episode 3521 Start ---
# 여긴 ego_vehicle12
# Episode done: Reached target point.
# Episode 3521: Reward = 22.00, Steps = 13
# --- Episode 3522 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3522: Reward = 28.00, Steps = 13
# --- Episode 3523 Start ---
# 여긴 ego_vehicle13
# Episode done: Reached target point.
# Episode 3523: Reward = 28.00, Steps = 13
# --- Episode 3524 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 3524: Reward = 24.00, Steps = 13
# --- Episode 3525 Start ---
# 여긴 ego_vehicle26
# Episode done: Reached target point.
# Episode 3525: Reward = -34.00, Steps = 12
# --- Episode 3526 Start ---
# 여긴 ego_vehicle23
# Episode done: Reached target point.
# Episode 3526: Reward = -26.00, Steps = 16
# --- Episode 3527 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3527: Reward = 28.00, Steps = 14
# --- Episode 3528 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3528: Reward = -10.00, Steps = 13
# --- Episode 3529 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3529: Reward = -14.00, Steps = 13
# --- Episode 3530 Start ---
# 여긴 ego_vehicle13
# Episode done: Reached target point.
# Episode 3530: Reward = 8.00, Steps = 15
# --- Episode 3531 Start ---
# 여긴 ego_vehicle13
# Episode done: Reached target point.
# Episode 3531: Reward = 16.00, Steps = 12
# --- Episode 3532 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 3532: Reward = 28.00, Steps = 13
# --- Episode 3533 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 3533: Reward = 8.00, Steps = 13
# --- Episode 3534 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3534: Reward = 2.00, Steps = 14
# --- Episode 3535 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 3535: Reward = -23.00, Steps = 13
# --- Episode 3536 Start ---
# 여긴 ego_vehicle25
# Episode done: Reached target point.
# Episode 3536: Reward = 0.00, Steps = 13
# --- Episode 3537 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3537: Reward = -14.00, Steps = 13
# --- Episode 3538 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3538: Reward = -30.00, Steps = 14
# --- Episode 3539 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3539: Reward = 28.00, Steps = 13
# --- Episode 3540 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3540: Reward = -9.00, Steps = 14
# --- Episode 3541 Start ---
# 여긴 ego_vehicle13
# Episode done: Reached target point.
# Episode 3541: Reward = 2.00, Steps = 15
# --- Episode 3542 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 3542: Reward = -6.00, Steps = 13
# --- Episode 3543 Start ---
# 여긴 ego_vehicle22
# Episode 3543: Reward = -227.00, Steps = 8
# --- Episode 3544 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 3544: Reward = 2.00, Steps = 13
# --- Episode 3545 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 3545: Reward = 2.00, Steps = 13
# --- Episode 3546 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 3546: Reward = 28.00, Steps = 13
# --- Episode 3547 Start ---
# 여긴 ego_vehicle24
# Episode done: Reached target point.
# Episode 3547: Reward = 22.00, Steps = 13
# --- Episode 3548 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 3548: Reward = -17.00, Steps = 13
# --- Episode 3549 Start ---
# 여긴 ego_vehicle23
# Episode done: Reached target point.
# Episode 3549: Reward = -19.00, Steps = 16
# --- Episode 3550 Start ---
# 여긴 ego_vehicle12
# Episode done: Reached target point.
# Episode 3550: Reward = 26.00, Steps = 13
# --- Episode 3551 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3551: Reward = -12.00, Steps = 14
# --- Episode 3552 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3552: Reward = -6.00, Steps = 14
# --- Episode 3553 Start ---
# 여긴 ego_vehicle12
# Episode done: Reached target point.
# Episode 3553: Reward = 28.00, Steps = 13
# --- Episode 3554 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 3554: Reward = 2.00, Steps = 14
# --- Episode 3555 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 3555: Reward = 18.00, Steps = 16
# --- Episode 3556 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 3556: Reward = 14.00, Steps = 13
# --- Episode 3557 Start ---

# %%
# net_path = "C:/Users/user/2_VISSIM_network/3_IG_RL/Network/rightTurn/"
# vissim = COM.Dispatch("Vissim.Vissim")
# vissim.LoadNet(net_path + "Signal intersection_v2.inpx")
# vissim.LoadLayout(net_path+"Signal intersection_v2.layx")

# for i in range(1000):
#     vissim.Simulation.RunsingleStep()

# vissim.Simulation.AttValue('SimSec')
# scs = vnet.SignalControllers
# sc = scs.ItemByKey(10)
# vissim.Net.Vehicles.ItemByKey(1).AttValue('Lane')
