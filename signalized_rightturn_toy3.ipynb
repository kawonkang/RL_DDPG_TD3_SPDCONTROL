# %% [markdown]
# # 우회전 유스케이스 분석
#
# ![description](imgs/image_RT.png)

# %%
# 상태에 min_spacing등만 넣을게 아니라, min2_spacing 등 추가
# state 변경 8개
        # state = np.array([
        #     ego_speed,
        #     dtc_norm,
        #     time_to_Gn_norm,
        #     min_follow_spacing,
        #     min_follow_ttc,
        #     rel_speed_follow,
        #     min_cross_spacing,
        #     min_cross_pet
        # ], dtype=np.float32)
# 앞뒤차 4대

# %%
"""
VISSIM TD3 Template for Single-Ego Accel Control at Signalized Intersection
- Author: Kawon Kang
- Purpose: Single vehicle (ego) continuous accel guidance via TD3
- Control: action a_t [m/s^2] -> target desired speed (DesSpeed) for ego
- Safety layer + yellow dilemma rule as post-processing on action
"""

# basic libraries
import os
import sys
import random
import math
import time
from dataclasses import dataclass
from typing import Dict, Any, Tuple, Optional

# VISSIM COM
import win32com.client as COM

# data libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.rc('font', family='Malgun Gothic')
# %matplotlib inline
plt.rcParams['axes.unicode_minus'] = False


# -----------------------------
# PyTorch 기반 TD3
# -----------------------------

import torch
import torch.nn as nn
import torch.optim as optim


from collections import deque, defaultdict

# 재현성
torch.manual_seed(42)
np.random.seed(42)
random.seed(42)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# PPO, DDPG, TD3 모델

# %%
# =========================
# VISSIM 유틸 (원본 최대 유지)
# =========================
def is_vehicle_valid(vehicle):
    try:
        vehicle.AttValue('No')
        vehicle.AttValue('Speed')
        vehicle.AttValue('Pos')
        return True
    except:
        return False

def get_valid_vehicles(Vissim):
    try:
        vehicles = []
        for vehicle in Vissim.Net.Vehicles:
            try:
                vehicle_no = vehicle.AttValue('No')
                vehicle_pos = vehicle.AttValue('Pos')
                vehicle_speed = vehicle.AttValue('Speed')
                vehicle_link = vehicle.AttValue('Lane')
                if all(attr is not None for attr in [vehicle_no, vehicle_pos, vehicle_speed, vehicle_link]):
                    vehicles.append(vehicle)
            except:
                continue
        return vehicles
    except Exception as e:
        print(f"Error in get_valid_vehicles: {str(e)}")
        return []
def reset_network(Vissim):
        # try:
    Vissim.Simulation.Stop()
    try:
        for vehicle in list(Vissim.Net.Vehicles):
            try:
                Vissim.Net.Vehicles.RemoveVehicle(vehicle.AttValue('No'))
            except:
                continue
    except:
        pass
def create_vehicles(Vissim, link_ranges):
    # try:
    Vissim.Simulation.Stop()
    try:
        for vehicle in list(Vissim.Net.Vehicles):
            try:
                Vissim.Net.Vehicles.RemoveVehicle(vehicle.AttValue('No'))
            except:
                continue
    except:
        pass
    time.sleep(0.2)
    cv_rand = np.random.randint(1, 100)
    Vissim.Simulation.SetAttValue('RandSeed', cv_rand)
    Vissim.Simulation.RunSingleStep()

    for _ in range(np.random.randint(850,1000)): # 80~ 100초까지 warm-up 100초에 남직신호 시작
        Vissim.Simulation.RunSingleStep()
    
    created_vehicles = []
    regular_vehicles = [
        (11, link_ranges[1][0], link_ranges[1][1], 1), # link, start_pos, end_pos, veh_num
        (11, link_ranges[2][0], link_ranges[2][1], 2), 
        (11, link_ranges[3][0], link_ranges[3][1], 3),
        (11, link_ranges[4][0], link_ranges[4][1], 4)
    ]
    for link, start_pos, end_pos, veh_num in regular_vehicles:
        vehicle = Vissim.Net.Vehicles.AddVehicleAtLinkPosition( #주변 차량 생성
            100, link, (veh_num+1)//2 , np.random.uniform(start_pos, end_pos), 40, True #Type, Lane, Pos, DesSpeed, Interaction(Opt)-> 주변객체 상호작용 여부
        )
        if vehicle:
            vehicle.SetAttValue('DesSpeed', 40) # 물어보기
            # vehicle.SetAttValue('DesLane', random.choice([1,2])) # 조정필요
            created_vehicles.append(vehicle)
            time.sleep(0.1)

    ego_pos = np.random.uniform(50, 60) # 조정필요
    ego_vehicle = Vissim.Net.Vehicles.AddVehicleAtLinkPosition(
        630, 11, np.random.choice([1,2]), ego_pos, 50, True 
    )
    if ego_vehicle:
        ego_vehicle.SetAttValue('DesSpeed', 50)
        ego_vehicle.SetAttValue('DesLane', 1) # 우회전만 하라.
        created_vehicles.append(ego_vehicle)
        time.sleep(0.2)

    # follower_pos = ego_pos - 30
    # if follower_pos >= link_ranges[3][0]:
    #     follower = Vissim.Net.Vehicles.AddVehicleAtLinkPosition(
    #         100, 3, 1, follower_pos, 40, True 
    #     )
    #     if follower:
    #         follower.SetAttValue('DesSpeed', 50)
    #         created_vehicles.append(follower)

    if len(created_vehicles) > 3:
        time.sleep(0.2)
        Vissim.Simulation.RunSingleStep()
        return created_vehicles
    return None
    # except Exception as e:
    #     print(f"Error in create_vehicles: {str(e)}")
    #     return None

# %%
LINK_LENGTHS = {
    "11-1": 149.4,
    "11-2": 149.4,
    "10002-1": 39.76,
    "4-1": 18.22,
    "9-1": 160.03,
    "10009-1": 40.89,
    "7-1": 200.0  # 필요 시 실제 길이로 수정
}

def get_dist_to_conflict(link_id, pos, role="ego"):
    """상충 지점까지의 남은 거리(DTC) 계산"""
    dtc = 1000.0
    try:
        link_id = str(link_id)
        if role == "ego":
            if link_id in ["11-1", "11-2"]:
                dtc = (LINK_LENGTHS["11-1"] - pos) + LINK_LENGTHS["10002-1"] + LINK_LENGTHS["4-1"]
            elif link_id == "10002-1":
                dtc = (LINK_LENGTHS["10002-1"] - pos) + LINK_LENGTHS["4-1"]
            elif link_id == "4-1":
                dtc = (LINK_LENGTHS["4-1"] - pos)
            elif link_id == "7-1":
                dtc = -pos
        elif role == "other":
            if link_id == "9-1":
                dtc = (LINK_LENGTHS["9-1"] - pos) + LINK_LENGTHS["10009-1"]
            elif link_id == "10009-1":
                dtc = (LINK_LENGTHS["10009-1"] - pos)
            elif link_id == "7-1":
                dtc = -pos
    except:
        pass
    return dtc

def calculate_observations(vehicle_list, ego_num=5):
    """
    모든 차량에 대해 Spacing과 시간지표(TTC/PET)를 계산.
    obs_dict[key] = {
        'type': 'following' or 'crossing',
        'spacing': ...,
        'ttc': ... (following),
        'pet': ... (crossing),
        ...
    }
    """
    obs_dict = {}
    ego_vehicle = None
    
    # Ego 찾기
    for vehicle in vehicle_list:
        if vehicle.AttValue('No') == ego_num:
            ego_vehicle = vehicle
            break
    if not ego_vehicle:
        return obs_dict

    ego_link = str(ego_vehicle.AttValue('Lane'))
    ego_pos  = float(ego_vehicle.AttValue('Pos'))
    ego_speed = float(ego_vehicle.AttValue('Speed') or 0) / 3.6
    dtc_ego = get_dist_to_conflict(ego_link, ego_pos, role="ego")

    crossing_target_links = ["9-1", "10009-1"]

    for other_vehicle in vehicle_list:
        oid = other_vehicle.AttValue('No')
        if oid == ego_num:
            continue

        other_link = str(other_vehicle.AttValue('Lane'))
        other_pos = float(other_vehicle.AttValue('Pos'))
        other_speed = float(other_vehicle.AttValue('Speed') or 0) / 3.6
        
        # 1) 같은 차선: following
        if ego_link == other_link and other_pos > ego_pos:
            spacing = other_pos - ego_pos
            rel_speed = ego_speed - other_speed
            ttc = spacing / (rel_speed + 1e-6) if rel_speed > 0 else 100.0

            if spacing < 60:
                obs_dict[f"{ego_num}_{oid}"] = {
                    "type": "following",
                    "spacing": spacing,
                    "ttc": ttc,
                    "rel_speed": rel_speed
                }

        # 2) 교차 차선: crossing
        elif (other_link in crossing_target_links) and (dtc_ego > -5):
            dtc_other = get_dist_to_conflict(other_link, other_pos, role="other")
            if dtc_other > -5:
                spacing = max(0, dtc_ego) + max(0, dtc_other)
                tta_ego = dtc_ego / max(ego_speed, 0.1)
                tta_other = dtc_other / max(other_speed, 0.1)
                pet = abs(tta_ego - tta_other)

                if tta_ego < 20:
                    obs_dict[f"{ego_num}_{oid}"] = {
                        "type": "crossing",
                        "spacing": spacing,
                        "pet": pet,
                        "tta_ego": tta_ego,
                        "tta_other": tta_other
                    }

    return obs_dict


def get_reward(vehicle, obs_dict):
    if vehicle is None: return 0.0, False
    
    reward = 0.1 # 생존 보상
    done = False
    
    # 가장 위험한 값 추출 (Spacing도 보고, 시간도 봄)
    min_spacing = 1000.0
    min_time_metric = 1000.0 # TTC or PET
    
    for _, data in obs_dict.items():
        # 거리 갱신 (무조건 가까우면 장땡)
        if data['spacing'] < min_spacing:
            min_spacing = data['spacing']
        
        # 시간 갱신 (유형별로 위험도 판단)
        if data['type'] == 'following':
            if data['ttc'] < min_time_metric: min_time_metric = data['ttc']
        elif data['type'] == 'crossing':
            if data['pet'] < min_time_metric: min_time_metric = data['pet']

    # --------------------------------------------------------
    # [보상 로직] Spacing과 Time Metric을 모두 사용
    # --------------------------------------------------------
    
    # 1. Spacing 기반 (물리적 충돌 방지 - 최우선)
    if min_spacing < 2.0: # 쾅!
        reward -= 200
        return float(reward), True # 종료
    elif min_spacing < 5.0: # 너무 가깝다
        reward -= 10
    elif min_spacing < 10.0: # 불안하다
        reward -= 2

    # 2. Time 기반 (예측 위험 회피)
    # 거리가 좀 있어도(20m), 속도가 빨라서 TTC/PET가 1초면 위험한 상황
    if min_time_metric < 1.5: # 급위험
        reward -= 10
    elif min_time_metric < 3.0: # 주의
        reward -= 2

    # 3. 속도 보상 (추가)
    ego_speed = float(vehicle.AttValue('Speed') or 0)
    if 30 <= ego_speed <= 50:
        reward += 1.0

    return float(reward), done

# %%
def get_state(vehicles, obs_dict, ego_num, simsec):
    """
    State Vector (8차원 예시)
    0: ego_speed (0~1)
    1: ego_pos   (0~1)
    2: time_to_Gn (0~1, 0 = 이미 GN, 1 = 최대 대기)
    3: min_follow_spacing (0~1)
    4: min_follow_ttc     (0~1)
    5: rel_speed_follow   (~[-1,1] 내)
    6: min_cross_spacing  (0~1)
    7: min_cross_pet      (0~1)
    """
    try:
        ego_vehicle = next((v for v in vehicles if v.AttValue('No') == ego_num), None)
        if not ego_vehicle:
            return np.zeros(8, dtype=np.float32)

        # 1. Ego 정보
        ego_speed = float(ego_vehicle.AttValue('Speed') or 0) / 50.0   # 50 km/h 기준
        ego_link = ego_vehicle.AttValue('Lane')
        ego_pos  = float(ego_vehicle.AttValue('Pos'))
        dtc_ego = get_dist_to_conflict(ego_link, ego_pos, role="ego")
        dtc_norm = min(dtc_ego / 200.0, 1.0)  # 200 m 이상이면 1.0

        # 2. 신호까지 남은 시간 (예: 0~100초 구간 가정)
        #    실제로는 SignalController에서 GN까지 남은 시간 읽어오는게 맞고,
        #    일단은 simsec 기준으로 예시만 둠.
        time_to_Gn = max(0.0, 100.0 - float(simsec))   # 0~100
        time_to_Gn_norm = min(time_to_Gn / 100.0, 1.0)

        # 3. Following / Crossing 각각 최소값 초기화
        #    (1.0 = 충분히 안전 / 0.0 = 매우 위험 에 가깝게 정규화)
        min_follow_spacing = 1.0
        min_follow_ttc     = 1.0
        rel_speed_follow   = 0.0

        min_cross_spacing  = 1.0
        min_cross_pet      = 1.0

        if obs_dict:
            for obj_id, data in obs_dict.items():
                if data['type'] == 'following':
                    # spacing, ttc 정규화
                    spacing_norm = min(data['spacing'] / 100.0, 1.0)   # 100 m 이상이면 그냥 1.0
                    ttc_norm     = min(data['ttc']     / 20.0, 1.0)    # 20초 이상이면 1.0

                    if spacing_norm < min_follow_spacing:
                        min_follow_spacing = spacing_norm
                    if ttc_norm < min_follow_ttc:
                        min_follow_ttc = ttc_norm

                    # 대표 rel_speed는 "가장 위험한 following" 기준으로 잡고 싶으면
                    # spacing/ttc 같이 비교해서 따로 저장해도 되고,
                    # 여기서는 가장 작은 spacing 기준으로 업데이트 하는 형태 예시:
                    # (좀 더 깔끔하게 하려면 따로 인덱스 따서 관리해도 됨)
                    rel_speed_follow = data['rel_speed'] / 50.0  # km/h 기준이면 /50, m/s면 적절히 조정

                elif data['type'] == 'crossing':
                    spacing_norm = min(data['spacing'] / 100.0, 1.0)
                    pet_norm     = min(data['pet']     / 20.0, 1.0)

                    if spacing_norm < min_cross_spacing:
                        min_cross_spacing = spacing_norm
                    if pet_norm < min_cross_pet:
                        min_cross_pet = pet_norm

        state = np.array([
            ego_speed,
            dtc_norm,
            time_to_Gn_norm,
            min_follow_spacing,
            min_follow_ttc,
            rel_speed_follow,
            min_cross_spacing,
            min_cross_pet
        ], dtype=np.float32)

        return state

    except Exception as e:
        print(f"Error in get_state: {str(e)}")
        return np.zeros(8, dtype=np.float32)




def apply_action(vehicle_list, Vissim, acceleration):
    try:
        for vehicle in vehicle_list:
            if vehicle.AttValue('VehType') == '630':
                current_speed = vehicle.AttValue('Speed')  # km/h
                speed_ms = current_speed / 3.6
                delta_v = float(acceleration) * 0.1  # 0.1초 스텝
                new_speed_ms = speed_ms + delta_v
                new_speed_ms = max(30/3.6, min(new_speed_ms, 50/3.6))
                vehicle.SetAttValue('DesSpeed', new_speed_ms * 3.6)
                break
    except Exception as e:
        print(f"Error applying action: {str(e)}")


def is_episode_done(ego_vehicle, obs_dict):
    try:
        if ego_vehicle is None:
            return False
        
        ego_link = str(ego_vehicle.AttValue('Lane'))
        ego_pos  = float(ego_vehicle.AttValue('Pos'))

        # 목표 지점 도달
        if ego_link == "7-1" and ego_pos > 30:
            print("Episode done: Reached target point.")
            return True

        # 충돌 조건
        for _, data in obs_dict.items():
            if data['spacing'] < 2.0:
                return True

        # 비정상 속도
        speed = float(ego_vehicle.AttValue('Speed'))
        if speed < 0 or speed > 60:
            print("Abnormal speed detected:", speed)
            return True

        return False
    except Exception as e:
        print(f"Error checking episode completion: {str(e)}")
        return False


def Network(Network_Path, inpx_Name, layx_Name):
    # try:
    Vissim = COM.Dispatch("Vissim.Vissim")
    Filename = os.path.join(Network_Path, inpx_Name)
    flag_read_additionally = False
    Vissim.LoadNet(Filename, flag_read_additionally)
    Filename = os.path.join(Network_Path, layx_Name)
    Vissim.LoadLayout(Filename)
    for simRun in Vissim.Net.SimulationRuns:
        Vissim.Net.SimulationRuns.RemoveSimulationRun(simRun)
    return Vissim
    
    # except Exception as e:
    #     print(f"Error initializing Vissim: {str(e)}")
    #     return None

# %%
# =========================
# Replay Buffer (TD3용)
# =========================
class ReplayBuffer:
    def __init__(self, capacity=100000):
        self.buffer = deque(maxlen=capacity)

    def push(self, state, action, reward, next_state, done):
        # action: float 가속도
        self.buffer.append((np.array(state, dtype=np.float32),
                            float(action),
                            float(reward),
                            np.array(next_state, dtype=np.float32),
                            float(done)))

    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        states, actions, rewards, next_states, dones = zip(*batch)
        states      = np.array(states, dtype=np.float32)
        actions     = np.array(actions, dtype=np.float32).reshape(-1, 1)  # (B,1)
        rewards     = np.array(rewards, dtype=np.float32).reshape(-1, 1)
        next_states = np.array(next_states, dtype=np.float32)
        dones       = np.array(dones, dtype=np.float32).reshape(-1, 1)
        
        # 라이트 클립으로 수치 안정화
        states      = np.clip(states, -10, 10)
        next_states = np.clip(next_states, -10, 10)
        rewards     = np.clip(rewards, -100, 100)
        return states, actions, rewards, next_states, dones

    def __len__(self):
        return len(self.buffer)


# =========================
# TD3 네트워크
# =========================
class Actor(nn.Module):
    def __init__(self, state_dim, act_low=-3.0, act_high=3.0):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(state_dim, 1024), nn.ReLU(),
            nn.Linear(1024, 512), nn.ReLU(),
            nn.Linear(512, 256), nn.ReLU(),
            nn.Linear(256, 1), nn.Tanh()  # [-1, 1]
        )
        # 행동 스케일
        self.register_buffer("act_low",  torch.tensor([act_low], dtype=torch.float32))
        self.register_buffer("act_high", torch.tensor([act_high], dtype=torch.float32))

    def forward(self, s):
        u = self.net(s)  # [-1,1]
        return (self.act_high - self.act_low) * 0.5 * u + (self.act_high + self.act_low) * 0.5


class Critic(nn.Module):
    def __init__(self, state_dim):
        super().__init__()
        def qnet():
            return nn.Sequential(
                nn.Linear(state_dim + 1, 400), nn.ReLU(),
                nn.Linear(400, 300), nn.ReLU(),
                nn.Linear(300, 1)
            )
        self.q1 = qnet()
        self.q2 = qnet()

    def forward(self, s, a):
        sa = torch.cat([s, a], dim=-1)
        return self.q1(sa), self.q2(sa)

    def q1_only(self, s, a):
        sa = torch.cat([s, a], dim=-1)
        return self.q1(sa)


# =========================
# TD3 Agent (PyTorch)
# =========================
class TD3Agent:
    def __init__(
        self,
        state_dim=8, # 상태 차원
        act_low=-3.0, # 가감속 범위
        act_high=3.0,
        actor_lr=1.5e-5,
        critic_lr=1.5e-4,
        gamma=0.99,
        tau=0.001,
        policy_noise=0.2,
        noise_clip=0.5,
        policy_delay=2,
        batch_size=512,
        start_steps=5000,
        expl_noise=0.2
    ):
        self.state_dim   = state_dim
        self.act_low     = act_low
        self.act_high    = act_high
        self.gamma       = gamma
        self.tau         = tau
        self.policy_noise= policy_noise
        self.noise_clip  = noise_clip
        self.policy_delay= policy_delay
        self.batch_size  = batch_size
        self.start_steps = start_steps
        self.expl_noise  = expl_noise

        self.actor     = Actor(state_dim, act_low, act_high).to(device)
        self.actor_t   = Actor(state_dim, act_low, act_high).to(device)
        self.critic    = Critic(state_dim).to(device)
        self.critic_t  = Critic(state_dim).to(device)

        self.actor_t.load_state_dict(self.actor.state_dict())
        self.critic_t.load_state_dict(self.critic.state_dict())

        self.opt_actor  = optim.Adam(self.actor.parameters(), lr=actor_lr)
        self.opt_critic = optim.Adam(self.critic.parameters(), lr=critic_lr)

        self.replay_buffer = ReplayBuffer(capacity=100000)
        self.total_it = 0

        # 로깅
        self.training_metrics = {
            'critic_losses': [],
            'actor_losses': [],
            'q_values': [],
            'rewards': []
        }

    @torch.no_grad()
    def select_action(self, state, training=True):
        """
        state: np.ndarray (state_dim,)
        return: float acceleration in [act_low, act_high]
        """
        s = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)  # (1, state_dim)
        if training and self.total_it < self.start_steps:
            a = np.random.uniform(self.act_low, self.act_high)
            return float(a)

        a = self.actor(s).cpu().numpy()[0, 0]
        if training:
            a += np.random.normal(0, self.expl_noise)
        return float(np.clip(a, self.act_low, self.act_high))

    def train_step(self):
        if len(self.replay_buffer) < self.batch_size:
            return

        self.total_it += 1
        s, a, r, s2, d = self.replay_buffer.sample(self.batch_size)

        s  = torch.tensor(s,  dtype=torch.float32, device=device)
        a  = torch.tensor(a,  dtype=torch.float32, device=device)
        r  = torch.tensor(r,  dtype=torch.float32, device=device)
        s2 = torch.tensor(s2, dtype=torch.float32, device=device)
        d  = torch.tensor(d,  dtype=torch.float32, device=device)

        # ----- Critic update -----
        with torch.no_grad():
            a2 = self.actor_t(s2)
            noise = (torch.randn_like(a2) * self.policy_noise).clamp(-self.noise_clip, self.noise_clip)
            a2 = (a2 + noise).clamp(self.act_low, self.act_high)
            q1_t, q2_t = self.critic_t(s2, a2)
            y = r + self.gamma * (1.0 - d) * torch.min(q1_t, q2_t)

        q1, q2 = self.critic(s, a)
        critic_loss = (q1 - y).pow(2).mean() + (q2 - y).pow(2).mean()

        self.opt_critic.zero_grad()
        critic_loss.backward()
        nn.utils.clip_grad_norm_(self.critic.parameters(), 1.0)
        self.opt_critic.step()

        actor_loss = torch.tensor(0.0, device=device)
        # ----- Delayed policy update -----
        if self.total_it % self.policy_delay == 0:
            a_pred = self.actor(s)
            actor_loss = -self.critic.q1_only(s, a_pred).mean()
            self.opt_actor.zero_grad()
            actor_loss.backward()
            nn.utils.clip_grad_norm_(self.actor.parameters(), 1.0)
            self.opt_actor.step()

            # Polyak update
            with torch.no_grad():
                for p, pt in zip(self.actor.parameters(), self.actor_t.parameters()):
                    pt.data.mul_(1 - self.tau)
                    pt.data.add_(self.tau * p.data)
                for p, pt in zip(self.critic.parameters(), self.critic_t.parameters()):
                    pt.data.mul_(1 - self.tau)
                    pt.data.add_(self.tau * p.data)

        # 로깅
        with torch.no_grad():
            self.training_metrics['critic_losses'].append(float(critic_loss.item()))
            self.training_metrics['actor_losses'].append(float(actor_loss.item()) if self.total_it % self.policy_delay == 0 else np.nan)
            self.training_metrics['q_values'].append(float(q1.mean().item()))

    # 저장/로드 (경량)
    def save_models(self, path):
        os.makedirs(path, exist_ok=True)
        torch.save(self.actor.state_dict(),  os.path.join(path, "actor.pt"))
        torch.save(self.critic.state_dict(), os.path.join(path, "critic.pt"))
        np.save(os.path.join(path, "train_meta.npy"), {"total_it": self.total_it})

    def load_models(self, path):
        self.actor.load_state_dict(torch.load(os.path.join(path, "actor.pt"), map_location=device))
        self.critic.load_state_dict(torch.load(os.path.join(path, "critic.pt"), map_location=device))
        self.actor_t.load_state_dict(self.actor.state_dict())
        self.critic_t.load_state_dict(self.critic.state_dict())
        meta_path = os.path.join(path, "train_meta.npy")
        if os.path.exists(meta_path):
            meta = np.load(meta_path, allow_pickle=True).item()
            self.total_it = int(meta.get("total_it", 0))


# =========================
# 평가 루틴 (TD3)
# =========================
def evaluate(Vissim, agent, link_ranges, num_episodes=1000):
    results = []
    for episode in range(num_episodes):
        vehicles = None
        while vehicles is None:
            vehicles = create_vehicles(Vissim, link_ranges)
            time.sleep(0.1)
        if vehicles is None:
            continue

        episode_reward = 0.0
        step = 0
        while True:
            try:
                vehicles = get_valid_vehicles(Vissim)
                if not vehicles:
                    break
                ego_vehicle = None
                ego_vehicle = next((v for v in vehicles if v.AttValue('VehType') == '630'), None)
                if ego_vehicle is None:
                    break

                ego_num = ego_vehicle.AttValue('No')
                # ---- obs/state 생성 ----
                obs_dict = calculate_observations(vehicles, ego_num=ego_num)
                current_state = get_state(vehicles, obs_dict, ego_num=ego_num, simsec=Vissim.Simulation.AttValue('SimSec'))
                # ---- 액션 선택 및 적용 ----
                acceleration = agent.select_action(current_state, training=False)
                apply_action(vehicles, Vissim, acceleration)
                Vissim.Simulation.RunSingleStep()

                next_vehicles = get_valid_vehicles(Vissim)
                if not next_vehicles:
                    break

                next_obs = calculate_observations(next_vehicles, ego_num=ego_num, simsec=Vissim.Simulation.AttValue('SimSec'))
                next_state = get_state(next_vehicles, next_obs, ego_num=ego_num, simsec=Vissim.Simulation.AttValue('SimSec'))

                # ---- 보상 계산 ----
                reward, done = get_reward(ego_vehicle, next_obs)
                episode_reward += reward

                results.append({
                    'Episode': episode + 1,
                    'Step': step + 1,
                    'Speed': ego_vehicle.AttValue('Speed'),
                    'Position': ego_vehicle.AttValue('Pos'),
                    'Link': ego_vehicle.AttValue('Lane')
                })

                if done or is_episode_done(ego_vehicle, next_obs):
                    break
                step += 1
                time.sleep(0.05)

            except Exception as e:
                print(f"Error during evaluation step: {str(e)}")
                break
            
        print(f"Evaluation Episode {episode + 1}: Reward = {episode_reward:.2f}")
    return pd.DataFrame(results)

# %%
# =========================
# 학습 모니터 (원본 유지)
# =========================
class LearningMonitor:
    def __init__(self):
        self.metrics = defaultdict(list)
        self.episode_data = []
        self.episode_summaries = []

    def add_episode_data(self, data):
        """에피소드 데이터 추가"""
        self.episode_data.append(data)
         # 에피소드 인덱스
        ep_idx = len(self.episode_summaries) + 1

        if not data:
            summary = {
                'episode': ep_idx,
                'length': 0,
                'total_reward': 0.0,
                'success': False,
                'collision': False,
                'crossing_step': None
            }
        else:
            length = len(data)
            total_reward = sum(step['Reward'] for step in data)

            # 성공: Link 7-1 도달 여부
            success = any(step['Link'] == "7-1" for step in data)

            # 충돌: 보상 기준 혹은 Collision flag 있으면 그걸 써도 됨
            collision = any(step['Reward'] <= -100 for step in data)

            # 교차로 통과 시점
            crossing_step = None
            if success:
                for i, step in enumerate(data):
                    if step['Link'] == "7-1":
                        crossing_step = i + 1   # step index를 1부터 보고 싶으면 +1
                        break

            summary = {
                'episode': ep_idx,
                'length': length,
                'total_reward': float(total_reward),
                'success': bool(success),
                'collision': bool(collision),
                'crossing_step': crossing_step
            }

        self.episode_summaries.append(summary)




    def compute_metrics(self, window_size=100):
        """주요 성능 지표 계산"""
        if not self.episode_data:
            return {}
        recent_episodes = self.episode_data[-window_size:]

        # 1. 성공률 (Link 7 도달)
        successes = [ep for ep in recent_episodes if any(step['Link'] == "7-1" for step in ep)]
        success_rate = len(successes) / len(recent_episodes) if recent_episodes else 0.0
        
        # 2. 충돌률
        collisions = [ep for ep in recent_episodes if any(step['Reward'] <= -100 for step in ep)]
        collision_rate = len(collisions) / len(recent_episodes) if recent_episodes else 0.0
        
        # 3. 평균 에피소드 길이
        episode_lengths = [len(ep) for ep in recent_episodes]
        avg_episode_length = np.mean(episode_lengths) if episode_lengths else 0.0
        
        # 4. 평균 누적 보상
        cumulative_rewards = [sum(step['Reward'] for step in ep) for ep in recent_episodes]
        avg_reward = np.mean(cumulative_rewards) if cumulative_rewards else 0.0
        
        # 5. 교차로 통과 시간 (성공한 경우만)
        crossing_times = []
        for ep in successes:
            for i, step in enumerate(ep):
                if step['Link'] == "7-1":
                    crossing_times.append(i); break
        avg_crossing_time = np.mean(crossing_times) if crossing_times else 0

        metrics = {
            'success_rate': success_rate,
            'collision_rate': collision_rate,
            'avg_episode_length': avg_episode_length,
            'avg_reward': avg_reward,
            'avg_crossing_time': avg_crossing_time
        }

        # 메트릭 저장
        for k, v in metrics.items():
            self.metrics[k].append(v)
        return metrics

    def plot_learning_curves(self):
        """학습 진행 상황 시각화"""
        if not self.metrics:
            return
        
        fig, axes = plt.subplots(2, 2, figsize=(15, 10))
        fig.suptitle('Learning Progress for Intersection Crossing', fontsize=16)

        # 1. 성공률과 충돌률
        ax = axes[0, 0]
        ax.plot(self.metrics['success_rate'], label='Success Rate', color='green')
        ax.plot(self.metrics['collision_rate'], label='Collision Rate', color='red')
        ax.set_title('Success and Collision Rates'); ax.set_xlabel('Evaluation Window'); ax.set_ylabel('Rate'); ax.legend(); ax.grid(True)
        
        # 2. 평균 보상
        ax = axes[0, 1]
        ax.plot(self.metrics['avg_reward'], color='blue')
        ax.set_title('Average Episode Reward'); ax.set_xlabel('Evaluation Window'); ax.set_ylabel('Reward'); ax.grid(True)
        
        # 3. 평균 에피소드 길이
        ax = axes[1, 0]
        ax.plot(self.metrics['avg_episode_length'], color='purple')
        ax.set_title('Average Episode Length'); ax.set_xlabel('Evaluation Window'); ax.set_ylabel('Steps'); ax.grid(True)
        
        # 4. 평균 교차로 통과 시간
        ax = axes[1, 1]
        ax.plot(self.metrics['avg_crossing_time'], color='orange')
        ax.set_title('Average Crossing Time (Successful Episodes)'); ax.set_xlabel('Evaluation Window'); ax.set_ylabel('Steps'); ax.grid(True)
        plt.tight_layout(); plt.show()

    def save_metrics(self, filepath):
        """메트릭 저장"""
        df = pd.DataFrame(self.metrics); df.to_csv(filepath, index=False)

# %%
# =========================
# 메인 (TD3로 학습/평가)
# =========================
# mode="train"
def main(mode='train'):
    try:
        Network_Path = 'C:/Users/user/2_VISSIM_network/3_IG_RL/Network/rightTurn/'
        inpx_Name    = 'Signal intersection_v3.inpx'
        layx_Name    = 'Signal intersection_v3.layx'

        Vissim = Network(Network_Path, inpx_Name, layx_Name)
        # if Vissim is None:
        #     return

        # Vissim.Simulation.SetAttValue('SimRes', 1)
        # Vissim.Simulation.SetAttValue('SimPeriod', 3600)
        # Vissim.Simulation.SetAttValue('SimSpeed', 1)

        link_ranges = {1: (10, 30), 2: (100, 150), 3: (10, 30), 4: (100, 150)} # 조정필요

        agent = TD3Agent(
            state_dim=8, 
            act_low=-3.0, 
            act_high=+3.0,
            actor_lr=1.5e-5, 
            critic_lr=1.5e-4,
            gamma=0.99, 
            tau=0.001,
            policy_noise=0.2, 
            noise_clip=0.5,
            policy_delay=2, 
            batch_size=512,
            start_steps=3000, 
            expl_noise=0.2
        )
        monitor = LearningMonitor()
        if mode == 'train':
            n_episodes = 5000
            max_steps  = 2000

            for episode in range(n_episodes):
                try:
                    episode_reward = 0.0
                    step = 0
                    current_episode_data = []
                    print(f"--- Episode {episode + 1} Start ---")

                    vehicles = None
                    for _ in range(3):
                        vehicles = create_vehicles(Vissim, link_ranges)
                        
                        if vehicles:
                            
                            break
                        time.sleep(0.1)
                    if not vehicles:
                        print("Failed to create vehicles. Skipping episode.")
                        continue

                    ego_vehicle = next((v for v in vehicles if v.AttValue('VehType') == '630'), None)
                    print('여긴 ego_vehicle'+str(ego_vehicle.AttValue('No')))
                    ego_num = ego_vehicle.AttValue('No')
                    # 초기 obs/state
                    current_obs = calculate_observations(vehicles, ego_num=ego_num)
                    current_state = get_state(vehicles, current_obs, ego_num=ego_num, simsec=Vissim.Simulation.AttValue('SimSec'))

                    while step < max_steps:
                        try:
                            vehicles = get_valid_vehicles(Vissim)
                            if not vehicles:
                                break

                            ego_vehicle = next((v for v in vehicles if v.AttValue('VehType') == '630'), None)
                            if ego_vehicle is None:
                                break
                            ego_num = ego_vehicle.AttValue('No')
                            # 최신 obs/state 갱신
                            current_obs = calculate_observations(vehicles, ego_num=ego_num)
                            current_state = get_state(vehicles, current_obs, ego_num=ego_num, simsec=Vissim.Simulation.AttValue('SimSec'))

                            # 행동 선택 및 적용
                            acceleration = agent.select_action(current_state, training=True)
                            apply_action(vehicles, Vissim, acceleration)

                            Vissim.Simulation.RunSingleStep()

                            next_vehicles = get_valid_vehicles(Vissim)
                            if not next_vehicles:
                                break

                            next_obs = calculate_observations(next_vehicles, ego_num=ego_num)
                            next_state = get_state(next_vehicles, next_obs, ego_num=ego_num, simsec=Vissim.Simulation.AttValue('SimSec'))

                            reward, done = get_reward(ego_vehicle, next_obs)
                            if is_episode_done(ego_vehicle, next_obs):
                                done = True

                            episode_reward += float(reward)
                            agent.replay_buffer.push(current_state, acceleration, reward, next_state, done)
                            agent.train_step()

                            step_data = {
                                'Step': step + 1,
                                'Action': acceleration,
                                'Reward': float(reward),
                                'Speed': ego_vehicle.AttValue('Speed'),
                                'Position': ego_vehicle.AttValue('Pos'),
                                'Link': ego_vehicle.AttValue('Lane')
                            }
                            current_episode_data.append(step_data)

                            if done:
                                break
                            step += 1
                            time.sleep(0.05)
                        except Exception as e:
                            print(f"Error in step {step}: {str(e)}")
                            break

                    monitor.add_episode_data(current_episode_data)
                    print(f"Episode {episode + 1}: Reward = {episode_reward:.2f}, Steps = {step}")


                    if (episode + 1) % 100 == 0:
                        metrics = monitor.compute_metrics()
                        print("\nPerformance Metrics:")
                        print(f"Success Rate: {metrics['success_rate']:.2%}")
                        print(f"Collision Rate: {metrics['collision_rate']:.2%}")
                        print(f"Avg Episode Length: {metrics['avg_episode_length']:.1f}")
                        print(f"Avg Reward: {metrics['avg_reward']:.1f}")
                        print(f"Avg Crossing Time: {metrics['avg_crossing_time']:.1f}")
                        monitor.plot_learning_curves()
                        monitor.save_metrics(f'output/v3/training_metrics_toy_3_episode_{episode + 1}.csv')
                        agent.save_models(f'models/v3/checkpoint_{episode + 1}')

                except Exception as e:
                    print(f"Error in episode {episode + 1}: {str(e)}")
                    continue

                agent.save_models('models/v3/final')
                monitor.save_metrics('output/v3/final_training_metrics_toy3.csv')


        elif mode == 'evaluate':
            agent.load_models('models/v3/final')

        results_df = evaluate(Vissim, agent, link_ranges)
        results_df.to_csv('output/v3/evaluation_results_toy3.csv', index=False)

    except Exception as e:
        print(f"Critical error in main: {str(e)}")
    finally:
        if 'Vissim' in locals():
            try:
                Vissim.Simulation.Stop()
            except:
                pass

if __name__ == "__main__":
    main(mode='train')  # 필요 시 'evaluate'
# Out:
# --- Episode 1 Start ---
# 여긴 ego_vehicle19
# Episode 1: Reward = -463.60, Steps = 153
# --- Episode 2 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 2: Reward = 167.40, Steps = 193
# --- Episode 3 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 3: Reward = 162.80, Steps = 147
# --- Episode 4 Start ---
# 여긴 ego_vehicle12
# Episode done: Reached target point.
# Episode 4: Reward = 166.10, Steps = 150
# --- Episode 5 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 5: Reward = 158.10, Steps = 150
# --- Episode 6 Start ---
# 여긴 ego_vehicle23
# Episode done: Reached target point.
# Episode 6: Reward = -303.20, Steps = 147
# --- Episode 7 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 7: Reward = -274.10, Steps = 188
# --- Episode 8 Start ---
# 여긴 ego_vehicle15
# Episode 8: Reward = -524.20, Steps = 127
# --- Episode 9 Start ---
# 여긴 ego_vehicle24
# Episode done: Reached target point.
# Episode 9: Reward = -184.40, Steps = 155
# --- Episode 10 Start ---
# 여긴 ego_vehicle15
# Episode 10: Reward = -492.60, Steps = 123
# --- Episode 11 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 11: Reward = 161.70, Steps = 146
# --- Episode 12 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 12: Reward = -78.60, Steps = 153
# --- Episode 13 Start ---
# 여긴 ego_vehicle16
# Episode 13: Reward = -303.30, Steps = 126
# --- Episode 14 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 14: Reward = 163.90, Steps = 148
# --- Episode 15 Start ---
# 여긴 ego_vehicle24
# Episode done: Reached target point.
# Episode 15: Reward = -189.70, Steps = 152
# --- Episode 16 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 16: Reward = -168.30, Steps = 166
# --- Episode 17 Start ---
# 여긴 ego_vehicle13
# Episode done: Reached target point.
# Episode 17: Reward = 172.70, Steps = 156
# --- Episode 18 Start ---
# 여긴 ego_vehicle23
# Episode done: Reached target point.
# Episode 18: Reward = -298.50, Steps = 144
# --- Episode 19 Start ---
# 여긴 ego_vehicle26
# Episode done: Reached target point.
# Episode 19: Reward = 169.40, Steps = 153
# --- Episode 20 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 20: Reward = -316.50, Steps = 144
# --- Episode 21 Start ---
# 여긴 ego_vehicle13
# Episode done: Reached target point.
# Episode 21: Reward = 169.40, Steps = 153
# --- Episode 22 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 22: Reward = -68.40, Steps = 145
# --- Episode 23 Start ---
# 여긴 ego_vehicle22
# Episode done: Reached target point.
# Episode 23: Reward = -411.30, Steps = 176
# --- Episode 24 Start ---
# 여긴 ego_vehicle21
# Episode 24: Reward = -424.40, Steps = 125
# --- Episode 25 Start ---
# 여긴 ego_vehicle8
# Episode done: Reached target point.
# Episode 25: Reward = 84.50, Steps = 154
# --- Episode 26 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 26: Reward = -352.70, Steps = 162
# --- Episode 27 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 27: Reward = 122.10, Steps = 150
# --- Episode 28 Start ---
# 여긴 ego_vehicle17
# Episode 28: Reward = -171.50, Steps = 124
# --- Episode 29 Start ---
# 여긴 ego_vehicle25
# Episode done: Reached target point.
# Episode 29: Reward = -360.20, Steps = 157
# --- Episode 30 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 30: Reward = -86.80, Steps = 151
# --- Episode 31 Start ---
# 여긴 ego_vehicle12
# Episode done: Reached target point.
# Episode 31: Reward = -33.50, Steps = 154
# --- Episode 32 Start ---
# 여긴 ego_vehicle21
# Episode 32: Reward = -887.00, Steps = 99
# --- Episode 33 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 33: Reward = 68.70, Steps = 156
# --- Episode 34 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 34: Reward = 106.50, Steps = 154
# --- Episode 35 Start ---
# 여긴 ego_vehicle24
# Episode 35: Reward = -45.90, Steps = 140
# --- Episode 36 Start ---
# 여긴 ego_vehicle16
# Episode 36: Reward = -34.90, Steps = 150
# --- Episode 37 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 37: Reward = -327.70, Steps = 142
# --- Episode 38 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 38: Reward = 165.00, Steps = 149
# --- Episode 39 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 39: Reward = -106.60, Steps = 153
# --- Episode 40 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 40: Reward = -175.20, Steps = 167
# --- Episode 41 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 41: Reward = -598.80, Steps = 151
# --- Episode 42 Start ---
# 여긴 ego_vehicle9
# Episode done: Reached target point.
# Episode 42: Reward = 169.40, Steps = 153
# --- Episode 43 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 43: Reward = 168.30, Steps = 152
# --- Episode 44 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 44: Reward = -254.80, Steps = 151
# --- Episode 45 Start ---
# 여긴 ego_vehicle18
# Episode 45: Reward = -448.10, Steps = 98
# --- Episode 46 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 46: Reward = 171.60, Steps = 155
# --- Episode 47 Start ---
# 여긴 ego_vehicle18
# Episode 47: Reward = -113.60, Steps = 133
# --- Episode 48 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 48: Reward = -324.30, Steps = 146
# --- Episode 49 Start ---
# 여긴 ego_vehicle13
# Episode done: Reached target point.
# Episode 49: Reward = 182.80, Steps = 187
# --- Episode 50 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 50: Reward = -546.10, Steps = 148
# --- Episode 51 Start ---
# 여긴 ego_vehicle22
# Episode 51: Reward = -622.10, Steps = 98
# --- Episode 52 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 52: Reward = 57.30, Steps = 142
# --- Episode 53 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 53: Reward = 0.30, Steps = 152
# --- Episode 54 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 54: Reward = 171.60, Steps = 155
# --- Episode 55 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 55: Reward = -377.70, Steps = 152
# --- Episode 56 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 56: Reward = 168.30, Steps = 152
# --- Episode 57 Start ---
# 여긴 ego_vehicle16
# Episode 57: Reward = -569.60, Steps = 93
# --- Episode 58 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 58: Reward = 168.50, Steps = 154
# --- Episode 59 Start ---
# 여긴 ego_vehicle19
# Episode 59: Reward = -335.40, Steps = 135
# --- Episode 60 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 60: Reward = 125.70, Steps = 166
# --- Episode 61 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 61: Reward = 168.30, Steps = 152
# --- Episode 62 Start ---
# 여긴 ego_vehicle29
# Episode 62: Reward = -668.30, Steps = 136
# --- Episode 63 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 63: Reward = -258.20, Steps = 157
# --- Episode 64 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 64: Reward = -81.60, Steps = 163
# --- Episode 65 Start ---
# 여긴 ego_vehicle17
# Episode 65: Reward = -153.60, Steps = 153
# --- Episode 66 Start ---
# 여긴 ego_vehicle22
# Episode 66: Reward = -672.50, Steps = 94
# --- Episode 67 Start ---
# 여긴 ego_vehicle12
# Episode done: Reached target point.
# Episode 67: Reward = 171.60, Steps = 155
# --- Episode 68 Start ---
# 여긴 ego_vehicle23
# Episode done: Reached target point.
# Episode 68: Reward = -521.10, Steps = 158
# --- Episode 69 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 69: Reward = -374.10, Steps = 148
# --- Episode 70 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 70: Reward = 20.50, Steps = 154
# --- Episode 71 Start ---
# 여긴 ego_vehicle22
# Episode 71: Reward = -341.70, Steps = 122
# --- Episode 72 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 72: Reward = -250.30, Steps = 146
# --- Episode 73 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 73: Reward = 114.40, Steps = 143
# --- Episode 74 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 74: Reward = -428.70, Steps = 192
# --- Episode 75 Start ---
# 여긴 ego_vehicle9
# Episode done: Reached target point.
# Episode 75: Reward = 102.40, Steps = 143
# --- Episode 76 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 76: Reward = -401.20, Steps = 167
# --- Episode 77 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 77: Reward = 150.40, Steps = 183
# --- Episode 78 Start ---
# 여긴 ego_vehicle17
# Episode 78: Reward = -422.50, Steps = 114
# --- Episode 79 Start ---
# 여긴 ego_vehicle18
# Episode 79: Reward = -147.10, Steps = 128
# --- Episode 80 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 80: Reward = -49.40, Steps = 145
# --- Episode 81 Start ---
# 여긴 ego_vehicle21
# Episode 81: Reward = -646.60, Steps = 123
# --- Episode 82 Start ---
# 여긴 ego_vehicle17
# Episode 82: Reward = -139.60, Steps = 133
# --- Episode 83 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 83: Reward = -80.50, Steps = 144
# --- Episode 84 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 84: Reward = 196.90, Steps = 178
# --- Episode 85 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 85: Reward = 166.90, Steps = 158
# --- Episode 86 Start ---
# 여긴 ego_vehicle22
# Episode done: Reached target point.
# Episode 86: Reward = -134.40, Steps = 155
# --- Episode 87 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 87: Reward = 169.40, Steps = 153
# --- Episode 88 Start ---
# 여긴 ego_vehicle12
# Episode done: Reached target point.
# Episode 88: Reward = -289.40, Steps = 145
# --- Episode 89 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 89: Reward = 165.00, Steps = 149
# --- Episode 90 Start ---
# 여긴 ego_vehicle19
# Episode 90: Reward = -692.30, Steps = 96
# --- Episode 91 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 91: Reward = 164.50, Steps = 154
# --- Episode 92 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 92: Reward = -188.20, Steps = 157
# --- Episode 93 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 93: Reward = -184.40, Steps = 155
# --- Episode 94 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 94: Reward = -178.50, Steps = 174
# --- Episode 95 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 95: Reward = -121.30, Steps = 156
# --- Episode 96 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 96: Reward = 35.10, Steps = 160
# --- Episode 97 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 97: Reward = -119.80, Steps = 171
# --- Episode 98 Start ---
# 여긴 ego_vehicle22
# Episode done: Reached target point.
# Episode 98: Reward = -23.70, Steps = 162
# --- Episode 99 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 99: Reward = 18.70, Steps = 156
# --- Episode 100 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 100: Reward = -224.70, Steps = 162
#
# Performance Metrics:
# Success Rate: 93.00%
# Collision Rate: 23.00%
# Avg Episode Length: 149.5
# Avg Reward: -140.0
# Avg Crossing Time: 130.2
# --- Episode 101 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 101: Reward = 168.30, Steps = 152
# --- Episode 102 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 102: Reward = -504.60, Steps = 153
# --- Episode 103 Start ---
# 여긴 ego_vehicle19
# Episode 103: Reward = -686.40, Steps = 105
# --- Episode 104 Start ---
# 여긴 ego_vehicle21
# Episode 104: Reward = -464.30, Steps = 96
# --- Episode 105 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 105: Reward = -498.40, Steps = 175
# --- Episode 106 Start ---
# 여긴 ego_vehicle18
# Episode 106: Reward = -667.60, Steps = 133
# --- Episode 107 Start ---
# 여긴 ego_vehicle18
# Episode 107: Reward = -631.40, Steps = 115
# --- Episode 108 Start ---
# 여긴 ego_vehicle17
# Episode 108: Reward = -526.70, Steps = 92
# --- Episode 109 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 109: Reward = 107.30, Steps = 162
# --- Episode 110 Start ---
# 여긴 ego_vehicle18
# Episode 110: Reward = -431.30, Steps = 126
# --- Episode 111 Start ---
# 여긴 ego_vehicle13
# Episode done: Reached target point.
# Episode 111: Reward = 125.50, Steps = 144
# --- Episode 112 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 112: Reward = 174.90, Steps = 158
# --- Episode 113 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 113: Reward = 199.10, Steps = 180
# --- Episode 114 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 114: Reward = 162.80, Steps = 147
# --- Episode 115 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 115: Reward = -414.10, Steps = 148
# --- Episode 116 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 116: Reward = 53.00, Steps = 149
# --- Episode 117 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 117: Reward = 151.50, Steps = 144
# --- Episode 118 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 118: Reward = 173.80, Steps = 157
# --- Episode 119 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 119: Reward = 165.00, Steps = 149
# --- Episode 120 Start ---
# 여긴 ego_vehicle24
# Episode done: Reached target point.
# Episode 120: Reward = 49.70, Steps = 166
# --- Episode 121 Start ---
# 여긴 ego_vehicle22
# Episode done: Reached target point.
# Episode 121: Reward = -245.00, Steps = 149
# --- Episode 122 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 122: Reward = -795.70, Steps = 152
# --- Episode 123 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 123: Reward = 48.80, Steps = 147
# --- Episode 124 Start ---
# 여긴 ego_vehicle16
# Episode 124: Reward = -562.80, Steps = 101
# --- Episode 125 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 125: Reward = 25.00, Steps = 149
# --- Episode 126 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 126: Reward = 165.60, Steps = 155
# --- Episode 127 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 127: Reward = 116.60, Steps = 145
# --- Episode 128 Start ---
# 여긴 ego_vehicle22
# Episode done: Reached target point.
# Episode 128: Reward = -133.40, Steps = 165
# --- Episode 129 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 129: Reward = -335.60, Steps = 163
# --- Episode 130 Start ---
# 여긴 ego_vehicle18
# Episode 130: Reward = -181.80, Steps = 131
# --- Episode 131 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 131: Reward = 166.10, Steps = 150
# --- Episode 132 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 132: Reward = -129.80, Steps = 161
# --- Episode 133 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 133: Reward = 166.10, Steps = 150
# --- Episode 134 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 134: Reward = 169.40, Steps = 153
# --- Episode 135 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 135: Reward = 101.60, Steps = 155
# --- Episode 136 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 136: Reward = -255.50, Steps = 154
# --- Episode 137 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 137: Reward = 109.70, Steps = 146
# --- Episode 138 Start ---
# 여긴 ego_vehicle7
# Episode done: Reached target point.
# Episode 138: Reward = 167.20, Steps = 151
# --- Episode 139 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 139: Reward = 177.10, Steps = 160
# --- Episode 140 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 140: Reward = -83.70, Steps = 152
# --- Episode 141 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 141: Reward = 31.20, Steps = 141
# --- Episode 142 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 142: Reward = -465.00, Steps = 149
# --- Episode 143 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 143: Reward = 168.30, Steps = 152
# --- Episode 144 Start ---
# 여긴 ego_vehicle12
# Episode done: Reached target point.
# Episode 144: Reward = 170.50, Steps = 154
# --- Episode 145 Start ---
# 여긴 ego_vehicle21
# Episode 145: Reward = -59.10, Steps = 128
# --- Episode 146 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 146: Reward = 96.60, Steps = 145
# --- Episode 147 Start ---
# 여긴 ego_vehicle21
# Episode 147: Reward = -409.50, Steps = 124
# --- Episode 148 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 148: Reward = -161.40, Steps = 175
# --- Episode 149 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 149: Reward = -252.50, Steps = 164
# --- Episode 150 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 150: Reward = -424.10, Steps = 148
# --- Episode 151 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 151: Reward = -333.70, Steps = 152
# --- Episode 152 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 152: Reward = 33.20, Steps = 151
# --- Episode 153 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 153: Reward = -842.00, Steps = 179
# --- Episode 154 Start ---
# 여긴 ego_vehicle24
# Episode done: Reached target point.
# Episode 154: Reward = 82.20, Steps = 161
# --- Episode 155 Start ---
# 여긴 ego_vehicle23
# Episode 155: Reward = -696.30, Steps = 96
# --- Episode 156 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 156: Reward = 135.30, Steps = 162
# --- Episode 157 Start ---
# 여긴 ego_vehicle17
# Episode 157: Reward = -160.90, Steps = 130
# --- Episode 158 Start ---
# 여긴 ego_vehicle11
# Episode done: Reached target point.
# Episode 158: Reward = 155.00, Steps = 199
# --- Episode 159 Start ---
# 여긴 ego_vehicle19
# Episode 159: Reward = -388.30, Steps = 96
# --- Episode 160 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 160: Reward = 168.30, Steps = 152
# --- Episode 161 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 161: Reward = 93.00, Steps = 149
# --- Episode 162 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 162: Reward = 11.70, Steps = 146
# --- Episode 163 Start ---
# 여긴 ego_vehicle18
# Episode 163: Reward = -219.80, Steps = 131
# --- Episode 164 Start ---
# 여긴 ego_vehicle18
# Episode 164: Reward = -687.70, Steps = 102
# --- Episode 165 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 165: Reward = 171.60, Steps = 155
# --- Episode 166 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 166: Reward = -45.60, Steps = 143
# --- Episode 167 Start ---
# 여긴 ego_vehicle11
# Episode done: Reached target point.
# Episode 167: Reward = 165.00, Steps = 149
# --- Episode 168 Start ---
# 여긴 ego_vehicle24
# Episode 168: Reward = -188.30, Steps = 136
# --- Episode 169 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 169: Reward = -790.20, Steps = 157
# --- Episode 170 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 170: Reward = 170.50, Steps = 154
# --- Episode 171 Start ---
# 여긴 ego_vehicle17
# Episode 171: Reward = -460.70, Steps = 132
# --- Episode 172 Start ---
# 여긴 ego_vehicle22
# Episode done: Reached target point.
# Episode 172: Reward = -723.90, Steps = 150
# --- Episode 173 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 173: Reward = 187.00, Steps = 169
# --- Episode 174 Start ---
# 여긴 ego_vehicle24
# Episode done: Reached target point.
# Episode 174: Reward = -231.90, Steps = 150
# --- Episode 175 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 175: Reward = -29.40, Steps = 145
# --- Episode 176 Start ---
# 여긴 ego_vehicle16
# Episode 176: Reward = -689.60, Steps = 93
# --- Episode 177 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 177: Reward = 176.00, Steps = 159
# --- Episode 178 Start ---
# 여긴 ego_vehicle26
# Episode done: Reached target point.
# Episode 178: Reward = 178.20, Steps = 161
# --- Episode 179 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 179: Reward = -494.30, Steps = 166
# --- Episode 180 Start ---
# 여긴 ego_vehicle16
# Episode 180: Reward = -399.30, Steps = 126
# --- Episode 181 Start ---
# 여긴 ego_vehicle23
# Episode done: Reached target point.
# Episode 181: Reward = -289.10, Steps = 158
# --- Episode 182 Start ---
# 여긴 ego_vehicle13
# Episode done: Reached target point.
# Episode 182: Reward = 10.50, Steps = 164
# --- Episode 183 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 183: Reward = -286.90, Steps = 160
# --- Episode 184 Start ---
# 여긴 ego_vehicle21
# Episode 184: Reward = -996.30, Steps = 96
# --- Episode 185 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 185: Reward = 37.90, Steps = 168
# --- Episode 186 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 186: Reward = -467.20, Steps = 197
# --- Episode 187 Start ---
# 여긴 ego_vehicle24
# Episode done: Reached target point.
# Episode 187: Reward = -383.50, Steps = 154
# --- Episode 188 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 188: Reward = 161.70, Steps = 146
# --- Episode 189 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 189: Reward = 138.50, Steps = 144
# --- Episode 190 Start ---
# 여긴 ego_vehicle22
# Episode done: Reached target point.
# Episode 190: Reward = 119.80, Steps = 157
# --- Episode 191 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 191: Reward = 173.50, Steps = 194
# --- Episode 192 Start ---
# 여긴 ego_vehicle13
# Episode done: Reached target point.
# Episode 192: Reward = 167.20, Steps = 151
# --- Episode 193 Start ---
# 여긴 ego_vehicle8
# Episode done: Reached target point.
# Episode 193: Reward = 165.00, Steps = 149
# --- Episode 194 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 194: Reward = -308.40, Steps = 155
# --- Episode 195 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 195: Reward = -335.30, Steps = 176
# --- Episode 196 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 196: Reward = -501.50, Steps = 154
# --- Episode 197 Start ---
# 여긴 ego_vehicle18
# Episode 197: Reward = -617.60, Steps = 93
# --- Episode 198 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 198: Reward = -0.40, Steps = 155
# --- Episode 199 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 199: Reward = 168.30, Steps = 152
# --- Episode 200 Start ---
# 여긴 ego_vehicle18
# Episode 200: Reward = -306.50, Steps = 134
#
# Performance Metrics:
# Success Rate: 89.00%
# Collision Rate: 22.00%
# Avg Episode Length: 148.3
# Avg Reward: -149.1
# Avg Crossing Time: 130.1
# --- Episode 201 Start ---
# 여긴 ego_vehicle20
# Episode 201: Reward = -801.30, Steps = 146
# --- Episode 202 Start ---
# 여긴 ego_vehicle23
# Episode 202: Reward = -745.20, Steps = 137
# --- Episode 203 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 203: Reward = -809.50, Steps = 164
# --- Episode 204 Start ---
# 여긴 ego_vehicle19
# Episode 204: Reward = -614.70, Steps = 112
# --- Episode 205 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 205: Reward = -459.10, Steps = 158
# --- Episode 206 Start ---
# 여긴 ego_vehicle13
# Episode done: Reached target point.
# Episode 206: Reward = 16.00, Steps = 179
# --- Episode 207 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 207: Reward = 93.40, Steps = 143
# --- Episode 208 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 208: Reward = -29.70, Steps = 152
# --- Episode 209 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 209: Reward = 165.00, Steps = 149
# --- Episode 210 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 210: Reward = 59.70, Steps = 146
# --- Episode 211 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 211: Reward = 95.50, Steps = 144
# --- Episode 212 Start ---
# 여긴 ego_vehicle24
# Episode done: Reached target point.
# Episode 212: Reward = -27.70, Steps = 152
# --- Episode 213 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 213: Reward = -368.80, Steps = 151
# --- Episode 214 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 214: Reward = 165.00, Steps = 149
# --- Episode 215 Start ---
# 여긴 ego_vehicle13
# Episode done: Reached target point.
# Episode 215: Reward = -32.00, Steps = 159
# --- Episode 216 Start ---
# 여긴 ego_vehicle13
# Episode done: Reached target point.
# Episode 216: Reward = 170.50, Steps = 154
# --- Episode 217 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 217: Reward = 144.80, Steps = 147
# --- Episode 218 Start ---
# 여긴 ego_vehicle17
# Episode 218: Reward = -460.10, Steps = 138
# --- Episode 219 Start ---
# 여긴 ego_vehicle19
# Episode 219: Reward = -368.30, Steps = 136
# --- Episode 220 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 220: Reward = 163.90, Steps = 148
# --- Episode 221 Start ---
# 여긴 ego_vehicle22
# Episode done: Reached target point.
# Episode 221: Reward = -42.10, Steps = 148
# --- Episode 222 Start ---
# 여긴 ego_vehicle22
# Episode 222: Reward = -56.90, Steps = 130
# --- Episode 223 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 223: Reward = -481.50, Steps = 154
# --- Episode 224 Start ---
# 여긴 ego_vehicle17
# Episode 224: Reward = -648.30, Steps = 96
# --- Episode 225 Start ---
# 여긴 ego_vehicle16
# Episode 225: Reward = -489.30, Steps = 106
# --- Episode 226 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 226: Reward = -504.80, Steps = 151
# --- Episode 227 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 227: Reward = 170.50, Steps = 154
# --- Episode 228 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 228: Reward = -365.90, Steps = 150
# --- Episode 229 Start ---
# 여긴 ego_vehicle23
# Episode done: Reached target point.
# Episode 229: Reward = -221.30, Steps = 156
# --- Episode 230 Start ---
# 여긴 ego_vehicle17
# Episode 230: Reward = -566.10, Steps = 98
# --- Episode 231 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 231: Reward = -81.80, Steps = 161
# --- Episode 232 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 232: Reward = -114.60, Steps = 153
# --- Episode 233 Start ---
# 여긴 ego_vehicle19
# Episode 233: Reward = -861.00, Steps = 99
# --- Episode 234 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 234: Reward = -205.40, Steps = 145
# --- Episode 235 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 235: Reward = 42.20, Steps = 161
# --- Episode 236 Start ---
# 여긴 ego_vehicle22
# Episode 236: Reward = -695.40, Steps = 95
# --- Episode 237 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 237: Reward = -157.30, Steps = 166
# --- Episode 238 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 238: Reward = -353.60, Steps = 193
# --- Episode 239 Start ---
# 여긴 ego_vehicle7
# Episode done: Reached target point.
# Episode 239: Reward = 172.70, Steps = 156
# --- Episode 240 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 240: Reward = 153.70, Steps = 146
# --- Episode 241 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 241: Reward = 167.20, Steps = 151
# --- Episode 242 Start ---
# 여긴 ego_vehicle15
# Episode 242: Reward = -483.70, Steps = 102
# --- Episode 243 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 243: Reward = -5.00, Steps = 149
# --- Episode 244 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 244: Reward = -261.50, Steps = 154
# --- Episode 245 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 245: Reward = -289.50, Steps = 154
# --- Episode 246 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 246: Reward = 109.00, Steps = 149
# --- Episode 247 Start ---
# 여긴 ego_vehicle12
# Episode done: Reached target point.
# Episode 247: Reward = 169.40, Steps = 153
# --- Episode 248 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 248: Reward = 173.80, Steps = 157
# --- Episode 249 Start ---
# 여긴 ego_vehicle23
# Episode 249: Reward = -470.10, Steps = 98
# --- Episode 250 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 250: Reward = 161.70, Steps = 146
# --- Episode 251 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 251: Reward = -262.50, Steps = 164
# --- Episode 252 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 252: Reward = -367.60, Steps = 203
# --- Episode 253 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 253: Reward = -182.10, Steps = 148
# --- Episode 254 Start ---
# 여긴 ego_vehicle25
# Episode done: Reached target point.
# Episode 254: Reward = -520.40, Steps = 155
# --- Episode 255 Start ---
# 여긴 ego_vehicle13
# Episode done: Reached target point.
# Episode 255: Reward = -45.30, Steps = 156
# --- Episode 256 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 256: Reward = 178.40, Steps = 163
# --- Episode 257 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 257: Reward = -52.30, Steps = 166
# --- Episode 258 Start ---
# 여긴 ego_vehicle22
# Episode done: Reached target point.
# Episode 258: Reward = -389.00, Steps = 149
# --- Episode 259 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 259: Reward = 130.60, Steps = 165
# --- Episode 260 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 260: Reward = -111.40, Steps = 145
# --- Episode 261 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 261: Reward = 140.60, Steps = 145
# --- Episode 262 Start ---
# 여긴 ego_vehicle17
# Episode 262: Reward = -446.10, Steps = 98
# --- Episode 263 Start ---
# 여긴 ego_vehicle23
# Episode 263: Reward = -499.40, Steps = 95
# --- Episode 264 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 264: Reward = -112.80, Steps = 151
# --- Episode 265 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 265: Reward = 166.10, Steps = 150
# --- Episode 266 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 266: Reward = -160.90, Steps = 160
# --- Episode 267 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 267: Reward = 171.60, Steps = 155
# --- Episode 268 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 268: Reward = 159.50, Steps = 144
# --- Episode 269 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 269: Reward = -366.20, Steps = 187
# --- Episode 270 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 270: Reward = 141.10, Steps = 140
# --- Episode 271 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 271: Reward = -531.80, Steps = 161
# --- Episode 272 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 272: Reward = -168.50, Steps = 164
# --- Episode 273 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 273: Reward = -370.90, Steps = 160
# --- Episode 274 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 274: Reward = -20.70, Steps = 182
# --- Episode 275 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 275: Reward = 39.50, Steps = 144
# --- Episode 276 Start ---
# 여긴 ego_vehicle14
# Episode 276: Reward = -742.90, Steps = 130
# --- Episode 277 Start ---
# 여긴 ego_vehicle19
# Episode 277: Reward = -440.10, Steps = 98
# --- Episode 278 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 278: Reward = 152.00, Steps = 159
# --- Episode 279 Start ---
# 여긴 ego_vehicle12
# Episode done: Reached target point.
# Episode 279: Reward = 167.30, Steps = 182
# --- Episode 280 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 280: Reward = 75.90, Steps = 148
# --- Episode 281 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 281: Reward = 123.80, Steps = 147
# --- Episode 282 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 282: Reward = -85.40, Steps = 165
# --- Episode 283 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 283: Reward = -102.80, Steps = 151
# --- Episode 284 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 284: Reward = -279.90, Steps = 150
# --- Episode 285 Start ---
# 여긴 ego_vehicle25
# Episode done: Reached target point.
# Episode 285: Reward = -281.30, Steps = 156
# --- Episode 286 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 286: Reward = 161.70, Steps = 146
# --- Episode 287 Start ---
# 여긴 ego_vehicle22
# Episode 287: Reward = -665.90, Steps = 100
# --- Episode 288 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 288: Reward = 192.40, Steps = 183
# --- Episode 289 Start ---
# 여긴 ego_vehicle12
# Episode done: Reached target point.
# Episode 289: Reward = 166.10, Steps = 150
# --- Episode 290 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 290: Reward = -26.10, Steps = 148
# --- Episode 291 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 291: Reward = 43.00, Steps = 169
# --- Episode 292 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 292: Reward = -279.70, Steps = 152
# --- Episode 293 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 293: Reward = 136.20, Steps = 141
# --- Episode 294 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 294: Reward = 0.70, Steps = 156
# --- Episode 295 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 295: Reward = 169.40, Steps = 153
# --- Episode 296 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 296: Reward = 163.90, Steps = 148
# --- Episode 297 Start ---
# 여긴 ego_vehicle8
# Episode done: Reached target point.
# Episode 297: Reward = 22.90, Steps = 158
# --- Episode 298 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 298: Reward = 80.20, Steps = 161
# --- Episode 299 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 299: Reward = 162.80, Steps = 147
# --- Episode 300 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 300: Reward = -190.90, Steps = 160
#
# Performance Metrics:
# Success Rate: 88.00%
# Collision Rate: 18.00%
# Avg Episode Length: 149.0
# Avg Reward: -144.3
# Avg Crossing Time: 130.1
# --- Episode 301 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 301: Reward = -309.10, Steps = 138
# --- Episode 302 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 302: Reward = 44.30, Steps = 192
# --- Episode 303 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 303: Reward = 122.50, Steps = 154
# --- Episode 304 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 304: Reward = -193.50, Steps = 154
# --- Episode 305 Start ---
# 여긴 ego_vehicle20
# Episode 305: Reward = -566.90, Steps = 150
# --- Episode 306 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 306: Reward = -433.20, Steps = 197
# --- Episode 307 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 307: Reward = -86.00, Steps = 159
# --- Episode 308 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 308: Reward = -230.40, Steps = 205
# --- Episode 309 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 309: Reward = -161.00, Steps = 149
# --- Episode 310 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 310: Reward = 148.50, Steps = 154
# --- Episode 311 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 311: Reward = -430.90, Steps = 160
# --- Episode 312 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 312: Reward = -183.00, Steps = 149
# --- Episode 313 Start ---
# 여긴 ego_vehicle22
# Episode 313: Reward = -305.60, Steps = 133
# --- Episode 314 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 314: Reward = 162.80, Steps = 147
# --- Episode 315 Start ---
# 여긴 ego_vehicle19
# Episode 315: Reward = -633.50, Steps = 104
# --- Episode 316 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 316: Reward = -328.00, Steps = 189
# --- Episode 317 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 317: Reward = -151.70, Steps = 152
# --- Episode 318 Start ---
# 여긴 ego_vehicle24
# Episode done: Reached target point.
# Episode 318: Reward = -184.20, Steps = 157
# --- Episode 319 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 319: Reward = -318.40, Steps = 155
# --- Episode 320 Start ---
# 여긴 ego_vehicle13
# Episode done: Reached target point.
# Episode 320: Reward = 166.10, Steps = 150
# --- Episode 321 Start ---
# 여긴 ego_vehicle16
# Episode 321: Reward = -203.70, Steps = 122
# --- Episode 322 Start ---
# 여긴 ego_vehicle13
# Episode done: Reached target point.
# Episode 322: Reward = 160.60, Steps = 145
# --- Episode 323 Start ---
# 여긴 ego_vehicle25
# Episode done: Reached target point.
# Episode 323: Reward = -182.40, Steps = 155
# --- Episode 324 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 324: Reward = 161.70, Steps = 146
# --- Episode 325 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 325: Reward = 167.20, Steps = 151
# --- Episode 326 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 326: Reward = 159.20, Steps = 151
# --- Episode 327 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 327: Reward = -199.80, Steps = 161
# --- Episode 328 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 328: Reward = -186.90, Steps = 160
# --- Episode 329 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 329: Reward = 189.60, Steps = 175
# --- Episode 330 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 330: Reward = -92.00, Steps = 159
# --- Episode 331 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 331: Reward = -246.40, Steps = 155
# --- Episode 332 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 332: Reward = 68.90, Steps = 188
# --- Episode 333 Start ---
# 여긴 ego_vehicle12
# Episode done: Reached target point.
# Episode 333: Reward = 177.10, Steps = 160
# --- Episode 334 Start ---
# 여긴 ego_vehicle13
# Episode done: Reached target point.
# Episode 334: Reward = -56.20, Steps = 157
# --- Episode 335 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 335: Reward = -153.20, Steps = 187
# --- Episode 336 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 336: Reward = 81.20, Steps = 151
# --- Episode 337 Start ---
# 여긴 ego_vehicle21
# Episode 337: Reward = -870.90, Steps = 130
# --- Episode 338 Start ---
# 여긴 ego_vehicle22
# Episode done: Reached target point.
# Episode 338: Reward = -173.00, Steps = 149
# --- Episode 339 Start ---
# 여긴 ego_vehicle25
# Episode done: Reached target point.
# Episode 339: Reward = -156.80, Steps = 151
# --- Episode 340 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 340: Reward = 169.10, Steps = 160
# --- Episode 341 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 341: Reward = -360.00, Steps = 169
# --- Episode 342 Start ---
# 여긴 ego_vehicle20
# Episode 342: Reward = -536.00, Steps = 129
# --- Episode 343 Start ---
# 여긴 ego_vehicle21
# Episode 343: Reward = -167.80, Steps = 131
# --- Episode 344 Start ---
# 여긴 ego_vehicle17
# Episode 344: Reward = -439.00, Steps = 99
# --- Episode 345 Start ---
# 여긴 ego_vehicle15
# Episode 345: Reward = -435.40, Steps = 95
# --- Episode 346 Start ---
# 여긴 ego_vehicle23
# Episode 346: Reward = -333.10, Steps = 128
# --- Episode 347 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 347: Reward = 161.70, Steps = 146
# --- Episode 348 Start ---
# 여긴 ego_vehicle22
# Episode done: Reached target point.
# Episode 348: Reward = 170.50, Steps = 154
# --- Episode 349 Start ---
# 여긴 ego_vehicle16
# Episode 349: Reward = -143.10, Steps = 128
# --- Episode 350 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 350: Reward = 9.20, Steps = 161
# --- Episode 351 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 351: Reward = -29.30, Steps = 196
# --- Episode 352 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 352: Reward = 155.90, Steps = 148
# --- Episode 353 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 353: Reward = 144.10, Steps = 150
# --- Episode 354 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 354: Reward = -153.50, Steps = 154
# --- Episode 355 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 355: Reward = 168.30, Steps = 152
# --- Episode 356 Start ---
# 여긴 ego_vehicle21
# Episode 356: Reward = -67.90, Steps = 120
# --- Episode 357 Start ---
# 여긴 ego_vehicle17
# Episode 357: Reward = -627.80, Steps = 131
# --- Episode 358 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 358: Reward = 132.10, Steps = 150
# --- Episode 359 Start ---
# 여긴 ego_vehicle23
# Episode done: Reached target point.
# Episode 359: Reward = -314.30, Steps = 146
# --- Episode 360 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 360: Reward = -119.90, Steps = 160
# --- Episode 361 Start ---
# 여긴 ego_vehicle15
# Episode 361: Reward = -120.40, Steps = 125
# --- Episode 362 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 362: Reward = 58.90, Steps = 158
# --- Episode 363 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 363: Reward = 159.00, Steps = 149
# --- Episode 364 Start ---
# 여긴 ego_vehicle12
# Episode done: Reached target point.
# Episode 364: Reward = 167.20, Steps = 151
# --- Episode 365 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 365: Reward = -350.60, Steps = 153
# --- Episode 366 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 366: Reward = -53.90, Steps = 150
# --- Episode 367 Start ---
# 여긴 ego_vehicle17
# Episode 367: Reward = -497.20, Steps = 137
# --- Episode 368 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 368: Reward = 163.90, Steps = 148
# --- Episode 369 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 369: Reward = -233.00, Steps = 149
# --- Episode 370 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 370: Reward = -326.20, Steps = 177
# --- Episode 371 Start ---
# 여긴 ego_vehicle22
# Episode done: Reached target point.
# Episode 371: Reward = -185.00, Steps = 169
# --- Episode 372 Start ---
# 여긴 ego_vehicle12
# Episode done: Reached target point.
# Episode 372: Reward = 176.00, Steps = 159
# --- Episode 373 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 373: Reward = -341.20, Steps = 147
# --- Episode 374 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 374: Reward = -314.10, Steps = 148
# --- Episode 375 Start ---
# 여긴 ego_vehicle17
# Episode 375: Reward = -437.20, Steps = 97
# --- Episode 376 Start ---
# 여긴 ego_vehicle17
# Episode 376: Reward = -519.70, Steps = 102
# --- Episode 377 Start ---
# 여긴 ego_vehicle23
# Episode done: Reached target point.
# Episode 377: Reward = -257.30, Steps = 166
# --- Episode 378 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 378: Reward = 167.20, Steps = 151
# --- Episode 379 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 379: Reward = -461.50, Steps = 154
# --- Episode 380 Start ---
# 여긴 ego_vehicle21
# Episode 380: Reward = -630.50, Steps = 114
# --- Episode 381 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 381: Reward = 171.60, Steps = 155
# --- Episode 382 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 382: Reward = 163.90, Steps = 148
# --- Episode 383 Start ---
# 여긴 ego_vehicle18
# Episode 383: Reward = -486.90, Steps = 130
# --- Episode 384 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 384: Reward = -23.10, Steps = 158
# --- Episode 385 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 385: Reward = 58.80, Steps = 147
# --- Episode 386 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 386: Reward = 127.90, Steps = 148
# --- Episode 387 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 387: Reward = -184.90, Steps = 160
# --- Episode 388 Start ---
# 여긴 ego_vehicle22
# Episode done: Reached target point.
# Episode 388: Reward = -329.90, Steps = 150
# --- Episode 389 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 389: Reward = 51.00, Steps = 159
# --- Episode 390 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 390: Reward = 193.80, Steps = 187
# --- Episode 391 Start ---
# 여긴 ego_vehicle19
# Episode 391: Reward = -209.50, Steps = 124
# --- Episode 392 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 392: Reward = -507.10, Steps = 158
# --- Episode 393 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 393: Reward = 123.40, Steps = 153
# --- Episode 394 Start ---
# 여긴 ego_vehicle8
# Episode done: Reached target point.
# Episode 394: Reward = 170.50, Steps = 154
# --- Episode 395 Start ---
# 여긴 ego_vehicle12
# Episode done: Reached target point.
# Episode 395: Reward = 170.50, Steps = 154
# --- Episode 396 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 396: Reward = -390.00, Steps = 159
# --- Episode 397 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 397: Reward = 66.90, Steps = 158
# --- Episode 398 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 398: Reward = -9.60, Steps = 143
# --- Episode 399 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 399: Reward = -324.10, Steps = 148
# --- Episode 400 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 400: Reward = -334.90, Steps = 160
#
# Performance Metrics:
# Success Rate: 94.00%
# Collision Rate: 20.00%
# Avg Episode Length: 151.7
# Avg Reward: -131.8
# Avg Crossing Time: 131.0
# --- Episode 401 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 401: Reward = 75.00, Steps = 149
# --- Episode 402 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 402: Reward = -51.40, Steps = 145
# --- Episode 403 Start ---
# 여긴 ego_vehicle23
# Episode done: Reached target point.
# Episode 403: Reward = 54.60, Steps = 145
# --- Episode 404 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 404: Reward = -638.10, Steps = 188
# --- Episode 405 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 405: Reward = 114.50, Steps = 144
# --- Episode 406 Start ---
# 여긴 ego_vehicle30
# Episode 406: Reward = -811.20, Steps = 137
# --- Episode 407 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 407: Reward = 168.30, Steps = 152
# --- Episode 408 Start ---
# 여긴 ego_vehicle23
# Episode 408: Reward = -870.30, Steps = 96
# --- Episode 409 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 409: Reward = 115.70, Steps = 146
# --- Episode 410 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 410: Reward = -327.00, Steps = 149
# --- Episode 411 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 411: Reward = 138.20, Steps = 161
# --- Episode 412 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 412: Reward = 179.30, Steps = 162
# --- Episode 413 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 413: Reward = 170.50, Steps = 154
# --- Episode 414 Start ---
# 여긴 ego_vehicle21
# Episode 414: Reward = -749.90, Steps = 100
# --- Episode 415 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 415: Reward = -433.70, Steps = 152
# --- Episode 416 Start ---
# 여긴 ego_vehicle22
# Episode 416: Reward = -579.80, Steps = 131
# --- Episode 417 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 417: Reward = -89.70, Steps = 152
# --- Episode 418 Start ---
# 여긴 ego_vehicle18
# Episode 418: Reward = -420.50, Steps = 114
# --- Episode 419 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 419: Reward = -111.30, Steps = 156
# --- Episode 420 Start ---
# 여긴 ego_vehicle26
# Episode done: Reached target point.
# Episode 420: Reward = 171.60, Steps = 155
# --- Episode 421 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 421: Reward = 73.40, Steps = 153
# --- Episode 422 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 422: Reward = -98.50, Steps = 164
# --- Episode 423 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 423: Reward = -104.20, Steps = 157
# --- Episode 424 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 424: Reward = -490.50, Steps = 164
# --- Episode 425 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 425: Reward = -329.60, Steps = 143
# --- Episode 426 Start ---
# 여긴 ego_vehicle16
# Episode 426: Reward = -833.40, Steps = 95
# --- Episode 427 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 427: Reward = -220.20, Steps = 197
# --- Episode 428 Start ---
# 여긴 ego_vehicle12
# Episode done: Reached target point.
# Episode 428: Reward = 94.20, Steps = 161
# --- Episode 429 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 429: Reward = -322.20, Steps = 157
# --- Episode 430 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 430: Reward = -165.90, Steps = 150
# --- Episode 431 Start ---
# 여긴 ego_vehicle20
# Episode 431: Reward = -714.60, Steps = 103
# --- Episode 432 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 432: Reward = -86.10, Steps = 148
# --- Episode 433 Start ---
# 여긴 ego_vehicle12
# Episode done: Reached target point.
# Episode 433: Reward = 171.60, Steps = 155
# --- Episode 434 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 434: Reward = -459.80, Steps = 161
# --- Episode 435 Start ---
# 여긴 ego_vehicle23
# Episode done: Reached target point.
# Episode 435: Reward = 81.60, Steps = 155
# --- Episode 436 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 436: Reward = 200.20, Steps = 181
# --- Episode 437 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 437: Reward = -152.30, Steps = 146
# --- Episode 438 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 438: Reward = 109.50, Steps = 184
# --- Episode 439 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 439: Reward = -329.70, Steps = 152
# --- Episode 440 Start ---
# 여긴 ego_vehicle16
# Episode 440: Reward = -458.30, Steps = 96
# --- Episode 441 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 441: Reward = 76.30, Steps = 152
# --- Episode 442 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 442: Reward = 170.50, Steps = 154
# --- Episode 443 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 443: Reward = -312.40, Steps = 155
# --- Episode 444 Start ---
# 여긴 ego_vehicle21
# Episode 444: Reward = -182.00, Steps = 129
# --- Episode 445 Start ---
# 여긴 ego_vehicle22
# Episode done: Reached target point.
# Episode 445: Reward = -200.30, Steps = 146
# --- Episode 446 Start ---
# 여긴 ego_vehicle24
# Episode done: Reached target point.
# Episode 446: Reward = 62.00, Steps = 159
# --- Episode 447 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 447: Reward = 160.60, Steps = 145
# --- Episode 448 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 448: Reward = 176.00, Steps = 159
# --- Episode 449 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 449: Reward = -311.10, Steps = 158
# --- Episode 450 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 450: Reward = 163.90, Steps = 148
# --- Episode 451 Start ---
# 여긴 ego_vehicle12
# Episode done: Reached target point.
# Episode 451: Reward = 111.90, Steps = 148
# --- Episode 452 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 452: Reward = 169.40, Steps = 153
# --- Episode 453 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 453: Reward = 56.50, Steps = 154
# --- Episode 454 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 454: Reward = -124.00, Steps = 159
# --- Episode 455 Start ---
# 여긴 ego_vehicle12
# Episode done: Reached target point.
# Episode 455: Reward = 161.70, Steps = 146
# --- Episode 456 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 456: Reward = 167.20, Steps = 151
# --- Episode 457 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 457: Reward = 167.20, Steps = 151
# --- Episode 458 Start ---
# 여긴 ego_vehicle13
# Episode 458: Reward = -489.80, Steps = 111
# --- Episode 459 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 459: Reward = -273.50, Steps = 144
# --- Episode 460 Start ---
# 여긴 ego_vehicle18
# Episode 460: Reward = -671.40, Steps = 135
# --- Episode 461 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 461: Reward = 164.70, Steps = 156
# --- Episode 462 Start ---
# 여긴 ego_vehicle17
# Episode 462: Reward = -533.10, Steps = 128
# --- Episode 463 Start ---
# 여긴 ego_vehicle12
# Episode done: Reached target point.
# Episode 463: Reward = 168.30, Steps = 152
# --- Episode 464 Start ---
# 여긴 ego_vehicle15
# Episode done: Reached target point.
# Episode 464: Reward = 169.40, Steps = 153
# --- Episode 465 Start ---
# 여긴 ego_vehicle13
# Episode done: Reached target point.
# Episode 465: Reward = 127.60, Steps = 165
# --- Episode 466 Start ---
# 여긴 ego_vehicle12
# Episode done: Reached target point.
# Episode 466: Reward = -131.20, Steps = 167
# --- Episode 467 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 467: Reward = 88.60, Steps = 145
# --- Episode 468 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 468: Reward = -140.60, Steps = 183
# --- Episode 469 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 469: Reward = 155.70, Steps = 146
# --- Episode 470 Start ---
# 여긴 ego_vehicle21
# Episode done: Reached target point.
# Episode 470: Reward = 28.10, Steps = 150
# --- Episode 471 Start ---
# 여긴 ego_vehicle9
# Episode done: Reached target point.
# Episode 471: Reward = 172.70, Steps = 156
# --- Episode 472 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 472: Reward = -391.40, Steps = 185
# --- Episode 473 Start ---
# 여긴 ego_vehicle14
# Episode done: Reached target point.
# Episode 473: Reward = -293.90, Steps = 150
# --- Episode 474 Start ---
# 여긴 ego_vehicle22
# Episode 474: Reward = -623.00, Steps = 99
# --- Episode 475 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 475: Reward = 167.20, Steps = 151
# --- Episode 476 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 476: Reward = -139.80, Steps = 161
# --- Episode 477 Start ---
# 여긴 ego_vehicle18
# Episode done: Reached target point.
# Episode 477: Reward = -79.20, Steps = 147
# --- Episode 478 Start ---
# 여긴 ego_vehicle16
# Episode done: Reached target point.
# Episode 478: Reward = -614.10, Steps = 188
# --- Episode 479 Start ---
# 여긴 ego_vehicle19
# Episode done: Reached target point.
# Episode 479: Reward = -217.60, Steps = 193
# --- Episode 480 Start ---
# 여긴 ego_vehicle17
# Episode 480: Reward = -716.40, Steps = 105
# --- Episode 481 Start ---
# 여긴 ego_vehicle13
# Episode done: Reached target point.
# Episode 481: Reward = 73.20, Steps = 151
# --- Episode 482 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 482: Reward = -794.40, Steps = 145
# --- Episode 483 Start ---
# 여긴 ego_vehicle11
# Episode done: Reached target point.
# Episode 483: Reward = 168.30, Steps = 152
# --- Episode 484 Start ---
# 여긴 ego_vehicle21
# Episode 484: Reward = -782.10, Steps = 98
# --- Episode 485 Start ---
# 여긴 ego_vehicle20
# Episode done: Reached target point.
# Episode 485: Reward = -370.20, Steps = 157
# --- Episode 486 Start ---
# 여긴 ego_vehicle17
# Episode done: Reached target point.
# Episode 486: Reward = -317.90, Steps = 150
# --- Episode 487 Start ---
# 여긴 ego_vehicle17

# %%
# net_path = "C:/Users/user/2_VISSIM_network/3_IG_RL/Network/rightTurn/"
# vissim = COM.Dispatch("Vissim.Vissim")
# vissim.LoadNet(net_path + "Signal intersection_v2.inpx")
# vissim.LoadLayout(net_path+"Signal intersection_v2.layx")

# for i in range(1000):
#     vissim.Simulation.RunsingleStep()

# vissim.Simulation.AttValue('SimSec')
# scs = vnet.SignalControllers
# sc = scs.ItemByKey(10)
# vissim.Net.Vehicles.ItemByKey(1).AttValue('Lane')
